# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
#pyqtgraph -> fast plotting
import pyqtgraph as pg
from pyqtgraph.Qt import QtGui
# %gui qt5
import time
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %% [markdown]
# ### Load Data

# %%
#one person slow walk
#TLV Data Load
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\slowWalk.mat'))['tlvStream'][0]

# %%
#two people slow walk
#TLV Data Load
#loads of points
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\2PeopleMoving.mat'))['tlvStream'][0]

# %%
#three people walk
#TLV Data Load
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\3PeopleWalking.mat'))['tlvStream'][0]

# %%
#initialise variables
lostSync = False

#valid header variables and constant
magicBytes = np.array([2,1,4,3,6,5,8,7], dtype= 'uint8')

isMagicOk = False
isDataOk = False
gotHeader = False

frameHeaderLength = 52 #52 bytes long
tlvHeaderLengthInBytes = 8
pointLengthInBytes = 16
frameNumber = 1
targetFrameNumber = 0
targetLengthInBytes = 68

#graph constraints
weightThreshold = 0.2 #minimum distance between points
minClusterSize = 30

# %% [markdown]
# ### Plotting Setup

# %%
app = QtGui.QApplication([])
pg.setConfigOption('background','w')

# %%
win = pg.GraphicsWindow(title="Testing GUI")
plot1 = win.addPlot()
plot1.setXRange(-6,6)
plot1.setYRange(0,6)
plot1.setLabel('left',text = 'Y position (m)')
plot1.setLabel('bottom', text= 'X position (m)')
s1 = plot1.plot([],[],pen=None,symbol='o')

plot2 = win.addPlot()
plot2.setXRange(-6,6)
plot2.setYRange(0,6)
plot2.setLabel('left',text = 'Y position (m)')
plot2.setLabel('bottom', text= 'X position (m)')
s2 = plot2.plot([],[],pen=None,symbol='o')

# %% [markdown]
# ### Main Code

# %%
def dfs(vertexDf, edgeMatrix, startNode):
    
    visited = []
    dfsStack = [int(startNode)]

    while not(len(dfsStack) == 0):
        vertex = dfsStack.pop()
        if vertex not in visited:
            #find unvisited nodes
            unvisitedNodes = vertexDf['VertexID'].values[np.logical_not(np.isnan(edgeMatrix[int(vertex), :]))]
            unvisitedNodes = list(unvisitedNodes)
            visited.append(vertex)
            #add unvisited nodes to the stack
            for node in unvisitedNodes:
                if node not in visited:
                    dfsStack.append(node)
    return visited

# %%
def findCentroids(clusterList):
    centroids = np.array([])
    for cluster in clusterList:
        xMean = np.mean(cluster['X'].values)
        yMean = np.mean(cluster['Y'].values)
        if len(centroids) == 0:
            centroids = np.array([xMean,yMean])
        else:
            centroids = np.concatenate((centroids, np.array([xMean,yMean])), axis=0)
    return centroids

# %%
#clear plots
centroidData = list()
for tlvStream in tlvData:
    tlvStream = np.frombuffer(tlvStream, dtype = 'uint8')
    
    #tlv header
    index = 0
    #tlv header parsing
    tlvType = tlvStream[index:index+4].view(dtype=np.uint32)
    tlvLength = tlvStream[index+4:index+8].view(dtype=np.uint32)
    
    index += tlvHeaderLengthInBytes
    tlvDataLength = tlvLength - tlvHeaderLengthInBytes

    if tlvType == 6: 
        numberOfPoints = tlvDataLength/pointLengthInBytes
        p = tlvStream[index:index+tlvDataLength[0]].view(np.single)
        pointCloud = np.reshape(p,(4, int(numberOfPoints)),order="F")

        if not(pointCloud is None):
            #constrain point cloud to within the effective sensor range
            #range 1 < x < 6
            #azimuth -50 deg to 50 deg
            #check whether corresponding range and azimuth data are within the constraints

            effectivePointCloud = np.array([])
            for index in range(0, len(pointCloud[0,:])):
                if (pointCloud[0,index] > 1 and pointCloud[0,index] < 6) \
                and (pointCloud[1, index] > -50*np.pi/180 \
                     and pointCloud[1, index] < 50*np.pi/180):
        
                    #concatenate columns to the new point cloud
                    if len(effectivePointCloud) == 0:
                        effectivePointCloud = np.reshape(pointCloud[:, index], (4,1), order="F")
                    else:
                        point = np.reshape(pointCloud[:, index], (4,1),order="F")
                        effectivePointCloud = np.hstack((effectivePointCloud, point))
                        

            if len(effectivePointCloud) != 0:
                posX = np.multiply(effectivePointCloud[0,:], np.sin(effectivePointCloud[1,:]))
                posY = np.multiply(effectivePointCloud[0,:], np.cos(effectivePointCloud[1,:]))
#                 s1.setData(posX, posY) #pre filtering
#                 QtGui.QApplication.processEvents()
                #vertex dataframe
                vertexID = np.arange(len(posX))
                vertexDf = pd.DataFrame({'VertexID':vertexID, 'X':posX, 'Y':posY})
                #minimum number of points to qualify as a person
                if len(vertexDf.values) >= minClusterSize: #do you even have one cluster
                    #preallocate edgeMatrix
                    #edges are denoted by their respective weights
                    #undirected graph with constraint that two nodes can only be connected by one edge
                    edgeMatrix = np.zeros((len(posX), len(posY)))
                    #vertices are saved as np arrays
                    #evaluate edge Matrix and create graph
                    for rowIndex in range(0, edgeMatrix.shape[0]):
                        for colIndex in range(0, edgeMatrix.shape[1]):
                            if rowIndex == colIndex:
                                continue #diagonal element
                            elif edgeMatrix[rowIndex, colIndex] != 0:
                                continue #element already filled
                            else:
                                pointA = (vertexDf.values[rowIndex])[1:] #extract x y position disregarding the vertexID
                                pointB = (vertexDf.values[colIndex])[1:] #extract x y position disregarding the vertexID
                                length = euclidean(pointA, pointB)
                                #fill elements
                                edgeMatrix[rowIndex,colIndex] = length
                                edgeMatrix[colIndex, rowIndex] = length

                    #weight based reduction of graph/remove edges by replacing edge weight by np.NaN
                    weightMask = np.logical_or(np.greater(edgeMatrix,weightThreshold), np.equal(edgeMatrix, 0))
                    edgeMatrix[weightMask] = np.NaN

                    #perform DFS to find connected components
                    componentsList = list() #list of components
                    vertexList = list() #used to hold vertices that have been considered
                    for vertex in vertexDf['VertexID']:
                        if vertex not in vertexList:
                            visitedNodes = dfs(vertexDf, edgeMatrix, vertex)
                            componentsList.append(visitedNodes)
                            for vertex in visitedNodes:
                                if vertex not in vertexList:
                                    vertexList.append(vertex)

                    #use minimum cluster size to remove bad cluster matches
                    #and extract clusters
                    clusterList = list()
                    clusterDf = pd.DataFrame([])
                    for cluster in componentsList:
                        if len(cluster) >= minClusterSize:
                            pointCluster = vertexDf.loc[np.array(cluster)]
                            clusterList.append(pointCluster)
                            clusterDf = pd.concat([clusterDf, pointCluster], ignore_index=True)
                    #if clusters are found
                    if len(clusterDf.values) > 0:
#                         s2.setData(clusterDf['X'].values, clusterDf['Y'].values)
#                         QtGui.QApplication.processEvents()
                        #calculate centroid
                        centroids = list()
                        centroids = findCentroids(clusterList)
                        centroidData.append(centroids)
                    else:
                        centroidData.append(np.array([None, None]))
                else:
                    centroidData.append(np.array([None, None]))

# %%
#save as csv
for centroid in centroidData:
    if len(centroid) > 0:
        centroidsPerFrame = pd.DataFrame(np.expand_dims(centroid, axis=0), columns=['X', 'Y'])
        centroidsPerFrame['CentroidNumber'] = pd.Series(len(centroid)-1) #recode for other datasets
#         centroidsPerFrame.to_csv('testCSV.csv', mode='a', header=True, index=False)
    else:
        print('HERE')
        centroidsPerFrame = pd.DataFrame([])
#         centroidsPerFrame.to_csv('testCSV.csv', mode='a', header=True, index=False)

# %%
centroidsPerFrame
# Out:
#       X     Y  CentroidNumber
# 0  None  None               0

# %%
# Out:
# [[nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([1.7693778, 4.7601967], dtype=float32),
#  array([1.7501438, 4.7477846], dtype=float32),
#  array([1.8444643, 4.747338 ], dtype=float32),
#  array([1.7373655, 4.776371 ], dtype=float32),
#  array([1.7855494, 4.8128524], dtype=float32),
#  array([1.7367755, 4.794367 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.68846 , 4.696127], dtype=float32),
#  array([1.6249257, 4.706563 ], dtype=float32),
#  array([1.649368, 4.708099], dtype=float32),
#  array([1.6362295, 4.663597 ], dtype=float32),
#  array([1.6508406, 4.66136  ], dtype=float32),
#  array([1.5833967, 4.6453   ], dtype=float32),
#  array([1.5920286, 4.617378 ], dtype=float32),
#  array([1.6360652, 4.6178102], dtype=float32),
#  array([1.6777766, 4.58198  ], dtype=float32),
#  array([1.6834232, 4.5768766], dtype=float32),
#  array([1.6839863, 4.562917 ], dtype=float32),
#  array([1.7327425, 4.5924993], dtype=float32),
#  array([1.6903324, 4.5821524], dtype=float32),
#  array([1.6167294, 4.6050377], dtype=float32),
#  array([1.5513351, 4.6332383], dtype=float32),
#  array([1.5595604, 4.5891633], dtype=float32),
#  array([1.6272156, 4.5817003], dtype=float32),
#  array([1.611933 , 4.6088004], dtype=float32),
#  array([1.5404438, 4.609722 ], dtype=float32),
#  array([1.387637 , 4.6112914], dtype=float32),
#  array([1.3879119, 4.5581717], dtype=float32),
#  array([1.358979, 4.525238], dtype=float32),
#  array([1.5288123, 4.5383396], dtype=float32),
#  array([1.2814825, 4.568934 ], dtype=float32),
#  array([1.2642654, 4.570716 ], dtype=float32),
#  array([1.2903981, 4.5440207], dtype=float32),
#  array([1.4965314, 4.5582385], dtype=float32),
#  array([], dtype=float64),
#  array([1.5727324, 4.5588737], dtype=float32),
#  array([1.2963015, 4.5533357], dtype=float32),
#  array([1.4799875, 4.497794 ], dtype=float32),
#  array([1.3770603, 4.497307 ], dtype=float32),
#  array([1.5713251, 4.451835 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.3742675, 4.4991217], dtype=float32),
#  array([1.5574881, 4.423675 ], dtype=float32),
#  array([1.5698901, 4.5262895], dtype=float32),
#  array([1.435296, 4.473319], dtype=float32),
#  array([1.4189162, 4.388583 ], dtype=float32),
#  array([1.3382809, 4.4752398], dtype=float32),
#  array([1.3407724, 4.5238023], dtype=float32),
#  array([1.3266422, 4.5285883], dtype=float32),
#  array([1.6145127, 4.5355277], dtype=float32),
#  array([1.6223801, 4.5715756], dtype=float32),
#  array([1.6246247, 4.5670657], dtype=float32),
#  array([1.6522841, 4.58718  ], dtype=float32),
#  array([1.4038515, 4.5976887], dtype=float32),
#  array([1.3372256, 4.583232 ], dtype=float32),
#  array([1.3326386, 4.6132503], dtype=float32),
#  array([1.4245749, 4.570259 ], dtype=float32),
#  array([1.3532175, 4.556799 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.5388128, 4.5850782], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  array([1.4183795, 4.60393  ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  array([1.5580872, 4.560924 ], dtype=float32),
#  array([1.3439413, 4.5044513], dtype=float32),
#  array([1.2084174, 4.5829177], dtype=float32),
#  array([], dtype=float64),
#  array([1.6194447, 4.501517 ], dtype=float32),
#  array([1.6000925, 4.5200534], dtype=float32),
#  array([], dtype=float64),
#  array([1.6577425, 4.457282 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.181151 , 4.4129915], dtype=float32),
#  array([1.2019994, 4.3894677], dtype=float32),
#  array([1.3379486, 4.4672813], dtype=float32),
#  array([1.5965496, 4.4416475], dtype=float32),
#  array([1.2828448, 4.408748 ], dtype=float32),
#  array([1.5490927, 4.415764 ], dtype=float32),
#  array([1.5946301, 4.3828197], dtype=float32),
#  array([1.2471535, 4.337234 ], dtype=float32),
#  array([1.590038 , 4.3650017], dtype=float32),
#  array([1.7057217, 4.348579 ], dtype=float32),
#  array([1.2764065, 4.269841 ], dtype=float32),
#  array([1.2337356, 4.163023 ], dtype=float32),
#  array([1.6868141, 4.301978 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.6085147, 4.257301 ], dtype=float32),
#  array([1.6173478, 4.2160954], dtype=float32),
#  array([1.6829116, 4.20225  ], dtype=float32),
#  array([1.7005485, 4.149177 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.7904785, 4.0846434], dtype=float32),
#  array([1.7133654, 4.109717 ], dtype=float32),
#  array([1.7209803, 4.0326223], dtype=float32),
#  array([1.6995946, 4.011545 ], dtype=float32),
#  array([1.6613262, 3.960412 ], dtype=float32),
#  array([1.65817  , 3.9528751], dtype=float32),
#  array([1.7429917, 3.9314318], dtype=float32),
#  array([1.7304935, 3.9079428], dtype=float32),
#  array([1.5805572, 3.862986 ], dtype=float32),
#  array([1.6550018, 3.8099208], dtype=float32),
#  array([1.4993356, 3.787303 ], dtype=float32),
#  array([1.3548534, 3.7198327], dtype=float32),
#  array([1.3777696, 3.70275  ], dtype=float32),
#  array([1.3429829, 3.6343458], dtype=float32),
#  array([1.4106728, 3.621954 ], dtype=float32),
#  array([1.3423649, 3.5548759], dtype=float32),
#  array([1.5276736, 3.5668283], dtype=float32),
#  array([1.5300779, 3.5430393], dtype=float32),
#  array([1.5380497, 3.469125 ], dtype=float32),
#  array([1.4356433, 3.431037 ], dtype=float32),
#  array([1.4688685, 3.4132466], dtype=float32),
#  array([1.500419, 3.366833], dtype=float32),
#  array([1.5100803, 3.3264503], dtype=float32),
#  array([1.372929 , 3.2879477], dtype=float32),
#  array([1.6049627, 3.2659557], dtype=float32),
#  array([1.5594598, 3.2278528], dtype=float32),
#  array([1.5091976, 3.1907349], dtype=float32),
#  array([1.5327032, 3.1788616], dtype=float32),
#  array([1.5199404, 3.1321979], dtype=float32),
#  array([1.5327234, 3.1204612], dtype=float32),
#  array([1.4866556, 3.0232677], dtype=float32),
#  array([1.454615 , 3.0228512], dtype=float32),
#  array([1.4291472, 2.960829 ], dtype=float32),
#  array([1.4785522, 2.9558685], dtype=float32),
#  array([1.4705967, 2.9071317], dtype=float32),
#  array([1.4526129, 2.9095194], dtype=float32),
#  array([1.4861904, 2.879843 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.4820528, 2.8302786], dtype=float32),
#  array([1.4517109, 2.7922378], dtype=float32),
#  array([1.4231452, 2.7303288], dtype=float32),
#  array([1.4230233, 2.7301712], dtype=float32),
#  array([1.2604061, 2.604231 ], dtype=float32),
#  array([1.3053596, 2.589392 ], dtype=float32),
#  array([1.2262646, 2.5380094], dtype=float32),
#  array([1.2346276, 2.465481 ], dtype=float32),
#  array([1.3292075, 2.4931746], dtype=float32),
#  array([1.2661535, 2.4405293], dtype=float32),
#  array([1.2942344, 2.3438125], dtype=float32),
#  array([1.3521624, 2.3753655], dtype=float32),
#  [nan, nan],
#  array([1.3147613, 2.2832787], dtype=float32),
#  array([1.2179841, 2.2257707], dtype=float32),
#  array([1.2673224, 2.1900258], dtype=float32),
#  array([1.242171 , 2.1791096], dtype=float32),
#  array([1.2459022, 2.1968703], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  array([1.1551591, 2.0481122], dtype=float32),
#  array([1.131189, 2.054274], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  array([0.7960588, 1.630031 ], dtype=float32),
#  array([0.76735806, 1.6231291 ], dtype=float32),
#  array([0.72481054, 1.6575111 ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([0.5555718, 1.4615306], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([0.33988822, 1.4049181 ], dtype=float32),
#  array([0.2788531, 1.4284142], dtype=float32),
#  array([0.23698434, 1.4264137 ], dtype=float32),
#  array([0.20302114, 1.4209274 ], dtype=float32),
#  array([0.167524 , 1.4289467], dtype=float32),
#  array([0.183812 , 1.3958576], dtype=float32),
#  array([0.16289689, 1.372752  ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([-0.25526863,  1.3445928 ], dtype=float32),
#  array([-0.2797995,  1.3532813], dtype=float32),
#  array([-0.31274763,  1.3683233 ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  array([-0.37538925,  1.3891277 ], dtype=float32),
#  array([-0.39375234,  1.3703976 ], dtype=float32),
#  array([-0.41113847,  1.390929  ], dtype=float32),
#  array([-0.46259513,  1.4068817 ], dtype=float32),
#  [nan, nan],
#  array([-0.53557557,  1.4147133 ], dtype=float32),
#  array([-0.53106326,  1.4023786 ], dtype=float32),
#  array([-0.5934071,  1.4420012], dtype=float32),
#  [nan, nan],
#  array([-0.659253 ,  1.4339597], dtype=float32),
#  array([-0.6964251,  1.4097048], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([-0.8160015,  1.407285 ], dtype=float32),
#  array([-0.8504744,  1.3869292], dtype=float32),
#  [nan, nan],
#  array([-0.88559264,  1.4284003 ], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([-0.9914963,  1.553884 ], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  array([-1.0168027,  1.6527624], dtype=float32),
#  array([-1.0090929,  1.6864352], dtype=float32),
#  array([-1.0733994,  1.6823153], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([-1.1265043,  1.7729883], dtype=float32),
#  array([-1.1196401,  1.7873355], dtype=float32),
#  [nan, nan],
#  array([], dtype=float64),
#  array([-1.149499 ,  1.8401799], dtype=float32),
#  array([-1.2125884,  1.9117346], dtype=float32),
#  array([-1.3306344,  1.908473 ], dtype=float32),
#  array([-1.3401941,  1.977224 ], dtype=float32),
#  array([-1.2591281,  1.9326594], dtype=float32),
#  array([-1.2460966,  1.9865463], dtype=float32),
#  array([-1.2795781,  1.995062 ], dtype=float32),
#  array([-1.261216 ,  2.0396311], dtype=float32),
#  [nan, nan],
#  array([-1.234457 ,  2.0881953], dtype=float32),
#  array([], dtype=float64),
#  array([-1.3937583,  2.2302961], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([-1.4223144,  2.326847 ], dtype=float32),
#  array([-1.476813 ,  2.3159347], dtype=float32),
#  [nan, nan],
#  array([-1.4246671,  2.4587562], dtype=float32),
#  array([-1.329011 ,  2.4232655], dtype=float32),
#  array([-1.3206356,  2.5108104], dtype=float32),
#  array([-1.192257 ,  2.4742293], dtype=float32),
#  array([-1.3812083,  2.5788736], dtype=float32),
#  array([], dtype=float64),
#  array([-1.4726003,  2.6308167], dtype=float32),
#  array([-1.5165924,  2.7046223], dtype=float32),
#  array([-1.4618491,  2.7171655], dtype=float32),
#  array([-1.4161111,  2.7513802], dtype=float32),
#  array([-1.4949244,  2.8365731], dtype=float32),
#  array([-1.5459769,  2.8631234], dtype=float32),
#  array([-1.4562821,  2.9029753], dtype=float32),
#  array([-1.4582112,  2.8904889], dtype=float32),
#  array([-1.5052027,  2.9299755], dtype=float32),
#  array([-1.5041435,  2.919805 ], dtype=float32),
#  array([-1.5295658,  2.969769 ], dtype=float32),
#  [nan, nan],
#  array([-1.4928759,  3.0123866], dtype=float32),
#  array([-1.5178423,  3.0842788], dtype=float32),
#  array([-1.4395578,  3.1442528], dtype=float32),
#  [nan, nan],
#  array([-1.4455676,  3.1940513], dtype=float32),
#  array([-1.4424877,  3.2019563], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  array([-1.359992 ,  3.2746408], dtype=float32),
#  array([], dtype=float64),
#  array([-1.4071426,  3.3847756], dtype=float32),
#  array([], dtype=float64),
#  array([-1.462996 ,  3.4174206], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([-1.3663857,  3.6275744], dtype=float32),
#  array([-1.3690611,  3.6171553], dtype=float32),
#  array([-1.3743032,  3.6516109], dtype=float32),
#  array([-1.357848 ,  3.6685505], dtype=float32),
#  array([-1.3847189,  3.701168 ], dtype=float32),
#  [nan, nan],
#  array([-1.3732979,  3.734238 ], dtype=float32),
#  array([-1.2943399,  3.738558 ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  array([-1.3967052,  3.8014708], dtype=float32),
#  array([-1.4024926,  3.8234901], dtype=float32),
#  array([-1.3986492,  3.837106 ], dtype=float32),
#  array([-1.3138418,  3.8684556], dtype=float32),
#  array([-1.2977734,  3.8728673], dtype=float32),
#  array([-1.3607264,  3.930516 ], dtype=float32),
#  array([-1.2940098,  3.9457822], dtype=float32),
#  array([-1.2139109,  3.9272106], dtype=float32),
#  [nan, nan],
#  array([], dtype=float64),
#  array([-1.2073826,  3.9623892], dtype=float32),
#  array([-1.3333211,  4.015414 ], dtype=float32),
#  [nan, nan],
#  array([-1.3277036,  4.0948634], dtype=float32),
#  array([-1.22526  ,  4.0795817], dtype=float32),
#  [nan, nan],
#  array([-1.4087596,  4.0456696], dtype=float32),
#  array([-1.4238487,  4.0559797], dtype=float32),
#  array([-1.2916479,  4.087186 ], dtype=float32),
#  array([-1.2278717,  4.1116543], dtype=float32),
#  array([-1.2630569,  4.1639137], dtype=float32),
#  array([-1.4006048,  4.166117 ], dtype=float32),
#  array([], dtype=float64),
#  array([-1.4196868,  4.2683554], dtype=float32),
#  array([-1.3879641,  4.2652454], dtype=float32),
#  [nan, nan],
#  array([], dtype=float64),
#  array([-1.3755237,  4.3095684], dtype=float32),
#  array([-1.2469748,  4.330036 ], dtype=float32),
#  array([-1.1428815,  4.346044 ], dtype=float32),
#  array([-1.1372315,  4.2896347], dtype=float32),
#  array([-1.2666467,  4.3784127], dtype=float32),
#  array([-1.3269172,  4.3801365], dtype=float32),
#  array([-1.2397066,  4.308198 ], dtype=float32),
#  array([-1.1678586,  4.3417196], dtype=float32),
#  [nan, nan],
#  array([-1.1111101,  4.408264 ], dtype=float32),
#  [nan, nan],
#  array([-1.1076365,  4.475449 ], dtype=float32),
#  array([-1.0693129,  4.480054 ], dtype=float32),
#  array([-1.1178108,  4.4897103], dtype=float32),
#  array([-1.0438774,  4.5765142], dtype=float32),
#  array([-1.0603921,  4.53964  ], dtype=float32),
#  array([-1.0658467,  4.562175 ], dtype=float32),
#  array([-1.0571091,  4.602766 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  array([-0.94374067,  4.6108117 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([-0.9708396,  4.668184 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.1952746, 4.9593353], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.2185712, 4.8941627], dtype=float32),
#  array([], dtype=float64),
#  array([1.6812791, 4.883046 ], dtype=float32),
#  array([1.1964357, 4.845543 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.4796495, 4.832194 ], dtype=float32),
#  array([1.5642736, 4.8044467], dtype=float32),
#  array([1.6556702, 4.7616754], dtype=float32),
#  array([1.2529805, 4.7640204], dtype=float32),
#  array([1.5873051, 4.7384915], dtype=float32),
#  array([1.2220781, 4.676768 ], dtype=float32),
#  array([1.3237376, 4.663569 ], dtype=float32),
#  array([1.4744132, 4.6857758], dtype=float32),
#  array([1.2746321, 4.661034 ], dtype=float32),
#  array([1.2696422, 4.6018405], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.2880903, 4.5346165], dtype=float32),
#  array([1.5408401, 4.547189 ], dtype=float32),
#  array([1.3054917, 4.5062003], dtype=float32),
#  array([1.5299747, 4.4996924], dtype=float32),
#  array([1.5223765, 4.451987 ], dtype=float32),
#  array([1.4821107, 4.4698677], dtype=float32),
#  array([1.4908073, 4.426763 ], dtype=float32),
#  array([1.6192147, 4.371278 ], dtype=float32),
#  array([1.5957786, 4.393137 ], dtype=float32),
#  array([1.676426 , 4.3369107], dtype=float32),
#  array([1.6851937, 4.312405 ], dtype=float32),
#  array([1.6459713, 4.313329 ], dtype=float32),
#  array([1.6665552, 4.3088145], dtype=float32),
#  array([1.7267671, 4.271195 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.7302824, 4.2174516], dtype=float32),
#  array([1.632403 , 4.2106695], dtype=float32),
#  array([1.382301, 4.154416], dtype=float32),
#  array([1.5646994, 4.186394 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.6078224, 4.025345 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.693115, 3.979966], dtype=float32),
#  array([1.5927607, 3.9428825], dtype=float32),
#  array([1.6040957, 3.9409935], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.3282596, 3.8128023], dtype=float32),
#  array([], dtype=float64),
#  array([1.368916 , 3.7652678], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.574701 , 3.6258018], dtype=float32),
#  array([1.5354269, 3.6174643], dtype=float32),
#  array([1.6285323, 3.5915313], dtype=float32),
#  array([1.5508281, 3.6013756], dtype=float32),
#  array([1.5687522, 3.599586 ], dtype=float32),
#  array([1.597221 , 3.5439978], dtype=float32),
#  array([1.5972958, 3.5496278], dtype=float32),
#  array([1.5295786, 3.5570884], dtype=float32),
#  array([1.6167783, 3.5398893], dtype=float32),
#  array([1.6802883, 3.5006917], dtype=float32),
#  array([1.6470221, 3.5130286], dtype=float32),
#  array([1.6185379, 3.5183156], dtype=float32),
#  array([1.5153672, 3.5121772], dtype=float32),
#  array([1.4894804, 3.4780552], dtype=float32),
#  array([1.4319073, 3.4775913], dtype=float32),
#  array([1.4333661, 3.4901223], dtype=float32),
#  array([1.4055943, 3.5002518], dtype=float32),
#  array([1.3623178, 3.4399207], dtype=float32),
#  array([1.4068857, 3.344812 ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  array([1.412435 , 3.5911098], dtype=float32),
#  [nan, nan],
#  array([], dtype=float64),
#  array([1.5401663, 3.6215587], dtype=float32),
#  array([], dtype=float64),
#  array([1.4560586, 3.688042 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.6248305, 3.762359 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.3836439, 3.798116 ], dtype=float32),
#  array([1.4217534, 3.7945683], dtype=float32),
#  array([1.3782909, 3.8104277], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.5621167, 3.9245007], dtype=float32),
#  [nan, nan],
#  array([1.6076518, 4.001038 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.403564 , 3.9573731], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.6438277, 4.142984 ], dtype=float32),
#  array([1.6134671, 4.167767 ], dtype=float32),
#  array([1.3647013, 4.2147136], dtype=float32),
#  array([1.7580806, 4.205779 ], dtype=float32),
#  array([1.6719246, 4.2569785], dtype=float32),
#  array([1.6647437, 4.243417 ], dtype=float32),
#  array([1.7347066, 4.3081384], dtype=float32),
#  array([], dtype=float64),
#  array([1.8395205, 4.3200107], dtype=float32),
#  [nan, nan],
#  array([1.731884 , 4.3246536], dtype=float32),
#  array([1.7019874, 4.3553405], dtype=float32),
#  array([1.726263, 4.385165], dtype=float32),
#  array([1.7764117, 4.369973 ], dtype=float32),
#  array([1.6675856, 4.4439635], dtype=float32),
#  array([1.6734875, 4.45922  ], dtype=float32),
#  array([1.3629005, 4.523118 ], dtype=float32),
#  array([], dtype=float64),
#  array([1.6164836, 4.549032 ], dtype=float32),
#  array([1.3965311, 4.546719 ], dtype=float32),
#  array([1.6144639, 4.5598965], dtype=float32),
#  array([], dtype=float64),
#  array([1.6074991, 4.5858755], dtype=float32),
#  array([1.2874405, 4.5551114], dtype=float32),
#  array([], dtype=float64),
#  array([1.6097136, 4.648551 ], dtype=float32),
#  array([1.2653854, 4.640998 ], dtype=float32),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1.3207407, 4.7368903], dtype=float32),
#  array([1.3068284, 4.799195 ], dtype=float32),
#  array([1.2608219, 4.840757 ], dtype=float32),
#  array([1.2117068, 4.850812 ], dtype=float32),
#  array([1.2161466, 4.8963013], dtype=float32),
#  array([1.5475715, 4.8746476], dtype=float32),
#  array([], dtype=float64),
#  array([1.2497711, 4.9409184], dtype=float32),
#  array([1.2766539, 4.92771  ], dtype=float32),
#  array([1.2900901, 4.9154663], dtype=float32),
#  array([], dtype=float64),
#  array([1.1928179, 4.945667 ], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  array([1.1929966, 5.010992 ], dtype=float32),
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  [nan, nan],
#  array([], dtype=float64),
#  [nan, nan],
#  array([], dtype=float64),
#  array([-0.91593355,  4.984046  ], dtype=float32),
#  array([], dtype=float64),
#  array([-0.921372 ,  4.9879804], dtype=float32),
#  array([-0.9154255,  4.9343576], dtype=float32),
#  array([-0.91652596,  4.9289794 ], dtype=float32),
#  array([-0.89283323,  4.9061594 ], dtype=float32),
#  array([-0.95793205,  4.912673  ], dtype=float32),
#  array([-0.9734331,  4.869551 ], dtype=float32),
#  array([-1.0188804,  4.8545785], dtype=float32),
#  array([-1.0319495,  4.8393025], dtype=float32),
#  array([-1.0473049,  4.799126 ], dtype=float32),
#  array([-1.0180613,  4.783307 ], dtype=float32),
#  array([-1.1499548,  4.7416024], dtype=float32),
#  array([-1.1451489,  4.7092996], dtype=float32),
#  array([-1.2250029,  4.698167 ], dtype=float32),
#  array([-1.1815327,  4.6666117], dtype=float32),
#  array([-1.1950377,  4.6684813], dtype=float32),
#  array([-1.1722493,  4.64846  ], dtype=float32),
#  array([], dtype=float64),
#  [nan, nan],
#  array([-1.340748 ,  4.5742884], dtype=float32),
#  array([-1.3450112,  4.579708 ], dtype=float32),
#  array([-1.3992075,  4.5427823], dtype=float32),
#  array([-1.1482695,  4.476336 ], dtype=float32),
#  array([-1.127221 ,  4.4911275], dtype=float32),
#  array([-1.232381,  4.445458], dtype=float32),
#  array([-1.3646969,  4.431175 ], dtype=float32),
#  array([-1.2173678,  4.3424754], dtype=float32),
#  array([-1.3093593,  4.3379836], dtype=float32),
#  array([-1.4896375,  4.314552 ], dtype=float32),
#  array([-1.1795539,  4.2809424], dtype=float32),
#  array([-1.3357506,  4.238957 ], dtype=float32),
#  array([-1.3803924,  4.224955 ], dtype=float32),
#  array([-1.1983366,  4.1781154], dtype=float32),
#  array([], dtype=float64),
#  array([-1.4271545,  4.1421504], dtype=float32),
#  array([-1.3701283,  4.1377463], dtype=float32),
#  array([-1.4334062,  4.0889072], dtype=float32),
#  array([], dtype=float64),
#  array([-1.3715866,  4.020589 ], dtype=float32),
#  array([-1.3661146,  3.99367  ], dtype=float32),
#  array([-1.1994269,  3.9114983], dtype=float32),
#  array([-1.4225334,  3.8952186], dtype=float32),
#  array([-1.2749368,  3.898584 ], dtype=float32),
#  array([-1.4619622,  3.8748422], dtype=float32),
#  array([-1.518069 ,  3.8636184], dtype=float32),
#  array([-1.4799184,  3.8507025], dtype=float32),
#  array([-1.4850364,  3.7633812], dtype=float32),
#  array([-1.6482472,  3.7658687], dtype=float32),
#  array([-1.3335661,  3.742435 ], dtype=float32),
#  array([-1.261142 ,  3.6803775], dtype=float32),
#  array([-1.4960198,  3.6695826], dtype=float32),
#  array([-1.4167525,  3.6229231], dtype=float32),
#  array([-1.4601784,  3.586646 ], dtype=float32),
#  array([-1.4690459,  3.5847275], dtype=float32),
#  array([-1.3790116,  3.507021 ], dtype=float32),
#  array([-1.4593887,  3.4816048], dtype=float32),
#  array([-1.4874898,  3.4662015], dtype=float32),
#  array([-1.4733747,  3.4243762], dtype=float32),
#  array([-1.4270585,  3.3961911], dtype=float32),
#  array([-1.4140476,  3.3819454], dtype=float32),
#  array([-1.5214683,  3.325874 ], dtype=float32),
#  array([-1.2249538,  3.2850914], dtype=float32),
#  array([-1.4717742,  3.2643504], dtype=float32),
#  array([-1.3788991,  3.2231848], dtype=float32),
#  array([-1.3929147,  3.1842303], dtype=float32),
#  array([-1.5094222,  3.1611598], dtype=float32),
#  array([-1.5446508,  3.1152804], dtype=float32),
#  array([-1.5358236,  3.0968676], dtype=float32),
#  array([-1.4948602,  3.078997 ], dtype=float32),
#  array([-1.4936383,  3.0060115], dtype=float32),
#  array([-1.5262824,  2.999043 ], dtype=float32),
#  array([-1.6343629,  2.98072  ], dtype=float32),
#  array([-1.5400864,  2.9423532], dtype=float32),
#  array([-1.5713989,  2.9243531], dtype=float32),
#  array([-1.5937128,  2.9100614], dtype=float32),
#  array([-1.5424328,  2.878118 ], dtype=float32),
#  array([-1.5447388,  2.8280008], dtype=float32),
#  array([-1.5289501,  2.8181891], dtype=float32),
#  array([-1.5293082,  2.8061635], dtype=float32),
#  array([-1.5429273,  2.769543 ], dtype=float32),
#  array([-1.674155 ,  2.7357745], dtype=float32),
#  array([-1.5858526,  2.722488 ], dtype=float32),
#  array([-1.5004456,  2.6680686], dtype=float32),
#  array([-1.4975973,  2.668958 ], dtype=float32),
#  array([-1.5187689,  2.621177 ], dtype=float32),
#  array([-1.5663873,  2.6002927], dtype=float32),
#  array([-1.5028269,  2.5681944], dtype=float32),
#  array([-1.4380884,  2.5469265], dtype=float32),
#  array([-1.3782536,  2.5313194], dtype=float32),
#  array([-1.3974482,  2.5131097], dtype=float32),
#  array([-1.4317728,  2.4862845], dtype=float32),
#  array([-1.3689822,  2.454831 ], dtype=float32),
#  array([-1.4052645,  2.4461994], dtype=float32),
#  array([-1.3423398,  2.4426198], dtype=float32),
#  array([-1.3330704,  2.3365414], dtype=float32),
#  array([-1.3589916,  2.3282075], dtype=float32),
#  array([-1.2483938,  2.2764766], dtype=float32),
#  array([-1.2694083,  2.223716 ], dtype=float32),
#  array([-1.4191736,  2.2575982], dtype=float32),
#  array([-1.4058117,  2.2170973], dtype=float32),
#  array([-1.4300251,  2.2066329], dtype=float32),
#  array([-1.3846247,  2.1534684], dtype=float32),
#  array([-1.3632435,  2.1477337], dtype=float32),
#  array([-1.3463815,  2.0803487], dtype=float32),
#  array([-1.2520995,  2.0642917], dtype=float32),
#  ...]

# %%
np.expand_dims(centroid, axis=1)
# Out:
# array([[1.7693778],
#        [4.7601967]], dtype=float32)
# array([[1.7693778],
#        [4.7601967]], dtype=float32)
# array([[1.7693778],
#        [4.7601967]], dtype=float32)
# array([[1.7693778],
#        [4.7601967]], dtype=float32)

# %%
#plot first frame of two people walking after runnining throug algorithm
plt.figure()
cluster = clusterList[0]
plt.scatter(cluster['X'], cluster['Y'])
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)

# %% [markdown]
# #### Unit Tests

# %%
#dfs unit test and overall algorithm test set 
posX = np.array([2,2.1,2.2,2.1,2.2,2.2,5,5.1,5,4,5])
posY = np.array([4,4,4,3.8,3.9,3.95,2,2,2.1,4,5])

# %%
#unit test to check vertex and edge generation
posX = np.array([1,1,1,2,3])
posY = np.array([4,3,2,4,4])

# %%
#vertex dataframe
vertexID = np.arange(len(posX))
vertexDf = pd.DataFrame({'VertexID':vertexID, 'X':posX, 'Y':posY})
#minimum number of points to qualify as a person
if len(vertexDf.values) >= minClusterSize: #do you even have one cluster
    #preallocate edgeMatrix
    #edges are denoted by their respective weights
    #undirected graph with constraint that two nodes can only be connected by one edge
    edgeMatrix = np.zeros((len(posX), len(posY)))
    #vertices are saved as np arrays
    #evaluate edge Matrix and create graph
    for rowIndex in range(0, edgeMatrix.shape[0]):
        for colIndex in range(0, edgeMatrix.shape[1]):
            if rowIndex == colIndex:
                continue #diagonal element
            elif edgeMatrix[rowIndex, colIndex] != 0:
                continue #element already filled
            else:
                pointA = (vertexDf.values[rowIndex])[1:] #extract x y position disregarding the vertexID
                pointB = (vertexDf.values[colIndex])[1:] #extract x y position disregarding the vertexID
                length = euclidean(pointA, pointB)
                #fill elements
                edgeMatrix[rowIndex,colIndex] = length
                edgeMatrix[colIndex, rowIndex] = length

    #weight based reduction of graph/remove edges by replacing edge weight by np.NaN
    weightMask = np.logical_or(np.greater(edgeMatrix,weightThreshold), np.equal(edgeMatrix, 0))
    edgeMatrix[weightMask] = np.NaN

    #perform DFS to find connected components
    componentsList = list() #list of components
    vertexList = list() #used to hold vertices that have been considered
    for vertex in vertexDf['VertexID']:
        if vertex not in vertexList:
            visitedNodes = dfs(vertexDf, edgeMatrix, vertex)
            componentsList.append(visitedNodes)
            for vertex in visitedNodes:
                if vertex not in vertexList:
                    vertexList.append(vertex)
                    
    #use minimum cluster size to remove bad cluster matches
    #and extract clusters
    clusterList = list()
    for cluster in componentsList:
        if len(cluster) >= minClusterSize:
            pointCluster = vertexDf.loc[np.array(cluster)]
            clusterList.append(pointCluster)
            
else:
    print('NOT ENOUGH POINTS')

# %%
def dfs(vertexDf, edgeMatrix, startNode):
    
    visited = []
    dfsStack = [int(startNode)]

    while not(len(dfsStack) == 0):
        vertex = dfsStack.pop()
        if vertex not in visited:
            #find unvisited nodes
            unvisitedNodes = vertexDf['VertexID'].values[np.logical_not(np.isnan(edgeMatrix[int(vertex), :]))]
            unvisitedNodes = list(unvisitedNodes)
            visited.append(vertex)
            #add unvisited nodes to the stack
            for node in unvisitedNodes:
                if node not in visited:
                    dfsStack.append(node)
    return visited

# %%
#plot the first frame of two people walking
plt.figure()
plt.scatter(posX, posY)
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)

# %%
#plot first frame of two people walking after runnining throug algorithm
plt.figure()
for cluster in clusterList:
    plt.scatter(cluster['X'], cluster['Y'])
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)
