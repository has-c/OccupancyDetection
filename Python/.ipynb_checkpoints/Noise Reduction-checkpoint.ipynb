# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat

import time
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import time
import matplotlib.pyplot as plt
# %matplotlib qt5

# %%
t0 = time.time()
code_block
t1 = time.time()

total = t1-t0

# %% [markdown]
# ### Load Data

# %%
#one person slow walk
#TLV Data Load
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\slowWalk.mat'))['tlvStream'][0]

# %%
#two people slow walk
#TLV Data Load
#loads of points
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\2PeopleMoving.mat'))['tlvStream'][0]

# %%
#three people walk
#TLV Data Load
tlvData = (loadmat('C:\\Users\\hasna\\Documents\\GitHub\\OccupancyDetection\\Data\\Matlab Data\\3PeopleWalking.mat'))['tlvStream'][0]

# %%
#initialise variables
lostSync = False

#valid header variables and constant
magicBytes = np.array([2,1,4,3,6,5,8,7], dtype= 'uint8')

isMagicOk = False
isDataOk = False
gotHeader = False

frameHeaderLength = 52 #52 bytes long
tlvHeaderLengthInBytes = 8
pointLengthInBytes = 16
frameNumber = 1
targetFrameNumber = 0
targetLengthInBytes = 68

#graph constraints
weightThreshold = 0.2 #minimum distance between points
minClusterSize = 3

# %% [markdown]
# ### Plotting Setup

# %%
app = QtGui.QApplication([])
pg.setConfigOption('background','w')

# %%
win = pg.GraphicsWindow(title="Testing GUI")
plot1 = win.addPlot()
plot1.setXRange(-6,6)
plot1.setYRange(0,6)
plot1.setLabel('left',text = 'Y position (m)')
plot1.setLabel('bottom', text= 'X position (m)')
s1 = plot1.plot([],[],pen=None,symbol='o')

plot2 = win.addPlot()
plot2.setXRange(-6,6)
plot2.setYRange(0,6)
plot2.setLabel('left',text = 'Y position (m)')
plot2.setLabel('bottom', text= 'X position (m)')
s2 = plot2.plot([],[],pen=None,symbol='o')

# %% [markdown]
# ### Main Code

# %%
def iterativeDfs(vertexDf, edgeMatrix, startNode):
    
    visited = []
    dfsStack = [int(startNode)]

    while not(len(dfsStack) == 0):
        vertex = dfsStack.pop()
        if vertex not in visited:
            #find unvisited nodes
            unvisitedNodes = vertexDf['VertexID'].values[np.logical_not(np.isnan(edgeMatrix[int(vertex), :]))]
            unvisitedNodes = list(unvisitedNodes)
            visited.append(vertex)
            #add unvisited nodes to the stack
            for node in unvisitedNodes:
                if node not in visited:
                    dfsStack.append(node)
    return visited

# %%
def recursiveDfs(vertexDf, edgeMatrix, startNode, visited):
    
    if visited is None:
        #very first recursive iteration
        visited = set()
    visited.add(startNode)
    
    neighboursOfStart = vertexDf['VertexID'].values[np.logical_not(np.isnan(edgeMatrix[int(startNode), :]))]
    for nextNode in neighboursOfStart:
        if nextNode not in neighboursOfStart:
            recursiveDfs(vertexDf, edgeMatrix, nextNode, visited)
    return visited

# %%
def findCentroids(clusterList):
    centroids = np.array([])
    for cluster in clusterList:
        xMean = np.mean(cluster['X'].values)
        yMean = np.mean(cluster['Y'].values)
        if len(centroids) == 0:
            centroids = np.array([xMean,yMean])
        else:
            centroids = np.concatenate((centroids, np.array([xMean,yMean])), axis=0)
    return centroids

# %%
#clear plots
centroidData = list()
recursiveTiming  = list()
for tlvStream in tlvData:
    tlvStream = np.frombuffer(tlvStream, dtype = 'uint8')
    
    #tlv header
    index = 0
    #tlv header parsing
    tlvType = tlvStream[index:index+4].view(dtype=np.uint32)
    tlvLength = tlvStream[index+4:index+8].view(dtype=np.uint32)
    
    index += tlvHeaderLengthInBytes
    tlvDataLength = tlvLength - tlvHeaderLengthInBytes

    if tlvType == 6: 
        numberOfPoints = tlvDataLength/pointLengthInBytes
        p = tlvStream[index:index+tlvDataLength[0]].view(np.single)
        pointCloud = np.reshape(p,(4, int(numberOfPoints)),order="F")

        if not(pointCloud is None):
            #constrain point cloud to within the effective sensor range
            #range 1 < x < 6
            #azimuth -50 deg to 50 deg
            #check whether corresponding range and azimuth data are within the constraints

            effectivePointCloud = np.array([])
            for index in range(0, len(pointCloud[0,:])):
                if (pointCloud[0,index] > 1 and pointCloud[0,index] < 6) \
                and (pointCloud[1, index] > -50*np.pi/180 \
                     and pointCloud[1, index] < 50*np.pi/180):
        
                    #concatenate columns to the new point cloud
                    if len(effectivePointCloud) == 0:
                        effectivePointCloud = np.reshape(pointCloud[:, index], (4,1), order="F")
                    else:
                        point = np.reshape(pointCloud[:, index], (4,1),order="F")
                        effectivePointCloud = np.hstack((effectivePointCloud, point))
                        

            if len(effectivePointCloud) != 0:
                posX = np.multiply(effectivePointCloud[0,:], np.sin(effectivePointCloud[1,:]))
                posY = np.multiply(effectivePointCloud[0,:], np.cos(effectivePointCloud[1,:]))
                #time start
                t0 = time.time()
#                 s1.setData(posX, posY) #pre filtering
#                 QtGui.QApplication.processEvents()
                #vertex dataframe
                vertexID = np.arange(len(posX))
                vertexDf = pd.DataFrame({'VertexID':vertexID, 'X':posX, 'Y':posY})
                #minimum number of points to qualify as a person
                if len(vertexDf.values) >= minClusterSize: #do you even have one cluster
                    #preallocate edgeMatrix
                    #edges are denoted by their respective weights
                    #undirected graph with constraint that two nodes can only be connected by one edge
                    edgeMatrix = np.zeros((len(posX), len(posY)))
                    #vertices are saved as np arrays
                    #evaluate edge Matrix and create graph
                    for rowIndex in range(0, edgeMatrix.shape[0]):
                        for colIndex in range(0, edgeMatrix.shape[1]):
                            if rowIndex == colIndex:
                                continue #diagonal element
                            elif edgeMatrix[rowIndex, colIndex] != 0:
                                continue #element already filled
                            else:
                                pointA = (vertexDf.values[rowIndex])[1:] #extract x y position disregarding the vertexID
                                pointB = (vertexDf.values[colIndex])[1:] #extract x y position disregarding the vertexID
                                length = euclidean(pointA, pointB)
                                #fill elements
                                edgeMatrix[rowIndex,colIndex] = length
                                edgeMatrix[colIndex, rowIndex] = length

                    #weight based reduction of graph/remove edges by replacing edge weight by np.NaN
                    weightMask = np.logical_or(np.greater(edgeMatrix,weightThreshold), np.equal(edgeMatrix, 0))
                    edgeMatrix[weightMask] = np.NaN

                    #perform DFS to find connected components
                    componentsList = list() #list of components
                    vertexList = list() #used to hold vertices that have been considered
                    for vertex in vertexDf['VertexID']:
                        if vertex not in vertexList:
#                             visitedNodes = iterativeDfs(vertexDf, edgeMatrix, vertex)
#                             componentsList.append(visitedNodes)
                            visitedNodes = recursiveDfs(vertexDf, edgeMatrix, vertex, visited=None)
                            componentsList.append(list(visitedNodes))
                            for vertex in visitedNodes:
                                if vertex not in vertexList:
                                    vertexList.append(vertex)

                    #use minimum cluster size to remove bad cluster matches
                    #and extract clusters
                    clusterList = list()
                    clusterDf = pd.DataFrame([])
                    for cluster in componentsList:
                        if len(cluster) >= minClusterSize:
                            pointCluster = vertexDf.loc[np.array(cluster)]
                            clusterList.append(pointCluster)
                            clusterDf = pd.concat([clusterDf, pointCluster], ignore_index=True)
                    #if clusters are found
                    if len(clusterDf.values) > 0:
#                         s2.setData(clusterDf['X'].values, clusterDf['Y'].values)
#                         QtGui.QApplication.processEvents()
                        #calculate centroid
                        centroids = list()
                        centroids = findCentroids(clusterList)
                        centroidData.append(centroids)
                    else:
                        centroidData.append(np.array([None, None]))
                    
                    #stop time
                    t1 = time.time()
                    total = t1-t0
                    recursiveTiming.append(total)
                else:
                    centroidData.append(np.array([None, None]))

# %%
timingDf = pd.DataFrame({'Recursive': recursiveTiming, 'Iterative': iterativeTiming})
timingDf.to_csv('ClusteringAlgorithmTiming.csv', mode='a', header=False)

# %%
#plot timing characteristics
plt.figure()
plt.plot(timingDf['Recursive'])
plt.plot(timingDf['Iterative'])
plt.title('Timing Characteristics')
plt.xlabel('Instance')
plt.ylabel('Time (s)')
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
#save as csv
for centroid in centroidData:
    if len(centroid) > 0:
        if centroid.shape[0] > 2:
            centroid = centroid.reshape(len(centroid)//2,2)
            centroidsPerFrame = pd.DataFrame({'X':centroid[:,0], 'Y':centroid[:,1]})
        else:
            centroidsPerFrame = pd.DataFrame({'X':centroid[0], 'Y':centroid[1]}, index=range(1))
        centroidsPerFrame['CentroidNumber'] = pd.Series(np.arange(0,centroid.shape[0])) 
        centroidsPerFrame.to_csv('testCSV.csv', mode='a', header=True, index=False)
# Out:
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.590903  3.145848               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.449955  3.276826               0
#           X         Y  CentroidNumber
# 0 -1.391407  3.267585               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.419666  3.333584               0
#           X         Y  CentroidNumber
# 0 -1.486208  3.300754               0
#           X         Y  CentroidNumber
# 0 -1.459111  3.247559               0
#           X         Y  CentroidNumber
# 0 -1.423705  3.229475               0
#           X         Y  CentroidNumber
# 0 -1.451874  3.291969               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X        Y  CentroidNumber
# 0 -1.445773  3.23766               0
#           X         Y  CentroidNumber
# 0 -1.474081  3.291348               0
#           X         Y  CentroidNumber
# 0 -1.535918  3.286262               0
#           X         Y  CentroidNumber
# 0 -1.571014  3.261879               0
#           X         Y  CentroidNumber
# 0 -1.512702  3.240298               0
#           X         Y  CentroidNumber
# 0 -1.532245  3.238965               0
#           X         Y  CentroidNumber
# 0 -1.513908  3.216664               0
#           X         Y  CentroidNumber
# 0 -1.523317  3.216073               0
#           X         Y  CentroidNumber
# 0 -1.489496  3.206275               0
#           X        Y  CentroidNumber
# 0 -1.480994  3.18391               0
#           X         Y  CentroidNumber
# 0 -1.593183  3.161947               0
#           X         Y  CentroidNumber
# 0 -1.490867  3.159193               0
#           X         Y  CentroidNumber
# 0 -1.582148  3.177814               0
#           X         Y  CentroidNumber
# 0 -1.579334  3.151993               0
#           X         Y  CentroidNumber
# 0 -1.409642  3.121026               0
#           X         Y  CentroidNumber
# 0 -1.492265  3.103651               0
#           X         Y  CentroidNumber
# 0 -1.515294  3.129562               0
#           X         Y  CentroidNumber
# 0 -1.503831  3.122064               0
#           X         Y  CentroidNumber
# 0 -1.498258  3.104754               0
#           X         Y  CentroidNumber
# 0 -1.531533  3.047964               0
#           X        Y  CentroidNumber
# 0 -1.499878  3.06076               0
#           X         Y  CentroidNumber
# 0 -1.499972  3.070688               0
#           X         Y  CentroidNumber
# 0 -1.497831  3.057724               0
# 1  1.255950  3.819218               1
#           X       Y  CentroidNumber
# 0 -1.468384  3.0023               0
#           X         Y  CentroidNumber
# 0 -1.456972  3.033458               0
# 1  1.279094  3.763737               1
#           X         Y  CentroidNumber
# 0 -1.531346  2.981321               0
#           X         Y  CentroidNumber
# 0 -1.466895  2.957027               0
#          X         Y  CentroidNumber
# 0 -1.53039  2.947745               0
#           X         Y  CentroidNumber
# 0 -1.502033  2.900942               0
#           X         Y  CentroidNumber
# 0 -1.520876  2.900116               0
#           X         Y  CentroidNumber
# 0 -1.460721  2.878316               0
#           X         Y  CentroidNumber
# 0 -1.441375  2.854463               0
#           X        Y  CentroidNumber
# 0 -1.522596  2.80865               0
#           X         Y  CentroidNumber
# 0 -1.408797  2.786969               0
#           X         Y  CentroidNumber
# 0 -1.467349  2.783104               0
#           X         Y  CentroidNumber
# 0 -1.362048  2.747358               0
#          X         Y  CentroidNumber
# 0 -1.47451  2.749126               0
#           X         Y  CentroidNumber
# 0 -1.424492  2.743065               0
#           X         Y  CentroidNumber
# 0 -1.458077  2.694407               0
#          X         Y  CentroidNumber
# 0 -1.47651  2.654951               0
#           X       Y  CentroidNumber
# 0 -1.506076  2.6276               0
#           X         Y  CentroidNumber
# 0 -1.502735  2.609668               0
#           X         Y  CentroidNumber
# 0 -1.472316  2.527830               0
# 1  1.368991  3.936406               1
#          X         Y  CentroidNumber
# 0 -1.48142  2.549576               0
#           X         Y  CentroidNumber
# 0 -1.505293  2.497694               0
# 1  1.645625  4.133739               1
#           X         Y  CentroidNumber
# 0 -1.469983  2.492309               0
# 1  1.363386  4.011583               1
#           X         Y  CentroidNumber
# 0 -1.481315  2.482294               0
#           X         Y  CentroidNumber
# 0 -1.405767  2.422528               0
# 1  1.339017  4.157072               1
#           X         Y  CentroidNumber
# 0 -1.433417  2.379177               0
# 1  1.583496  4.283775               1
#           X         Y  CentroidNumber
# 0 -1.410173  2.348468               0
# 1  1.343785  4.274193               1
#           X         Y  CentroidNumber
# 0 -1.406739  2.330759               0
# 1  1.329707  4.231408               1
#           X         Y  CentroidNumber
# 0 -1.472822  2.314836               0
# 1  1.355386  4.284245               1
#           X         Y  CentroidNumber
# 0 -1.421940  2.243145               0
# 1  1.378913  4.361987               1
#           X         Y  CentroidNumber
# 0 -1.430575  2.240154               0
# 1  1.346721  4.373305               1
#           X         Y  CentroidNumber
# 0 -1.461795  2.184508               0
# 1  1.526838  4.406849               1
#           X         Y  CentroidNumber
# 0 -1.325653  2.124053               0
# 1  1.324364  4.525313               1
#           X         Y  CentroidNumber
# 0 -1.411965  2.091738               0
# 1  1.432791  4.517188               1
#           X         Y  CentroidNumber
# 0 -1.369427  2.081424               0
# 1  1.307341  4.518398               1
#           X         Y  CentroidNumber
# 0 -1.290900  2.020318               0
# 1  1.271409  4.591115               1
#           X         Y  CentroidNumber
# 0 -1.273679  2.020413               0
# 1  1.320258  4.565002               1
#           X         Y  CentroidNumber
# 0 -1.284081  2.008744               0
# 1  1.289678  4.560736               1
#           X         Y  CentroidNumber
# 0 -1.242452  1.985240               0
# 1  1.290588  4.605157               1
#           X         Y  CentroidNumber
# 0 -1.271210  1.959087               0
# 1  1.322207  4.612708               1
#           X         Y  CentroidNumber
# 0 -1.199009  1.907362               0
# 1  1.734379  4.634523               1
#           X         Y  CentroidNumber
# 0 -1.221383  1.922545               0
# 1  1.324968  4.685577               1
#           X         Y  CentroidNumber
# 0 -1.185962  1.888738               0
# 1  1.326899  4.698149               1
#           X         Y  CentroidNumber
# 0 -1.162574  1.835964               0
#           X         Y  CentroidNumber
# 0 -1.165542  1.842796               0
#           X         Y  CentroidNumber
# 0 -1.088284  1.774005               0
#           X         Y  CentroidNumber
# 0 -1.109042  1.706114               0
# 1  1.300798  4.952291               1
#           X         Y  CentroidNumber
# 0 -1.105055  1.624497               0
#           X         Y  CentroidNumber
# 0 -1.100044  1.616898               0
# 1  1.291476  4.912328               1
#           X         Y  CentroidNumber
# 0 -1.070284  1.669943               0
# 1  1.682287  4.946287               1
#           X        Y  CentroidNumber
# 0 -1.050713  1.63819               0
#           X         Y  CentroidNumber
# 0 -0.982142  1.618578               0
# 1  1.811749  4.926603               1
#           X         Y  CentroidNumber
# 0 -0.986955  1.606231               0
#           X         Y  CentroidNumber
# 0 -0.954075  1.591104               0
# 1  1.299127  4.977078               1
#           X         Y  CentroidNumber
# 0 -0.970759  1.619545               0
#           X         Y  CentroidNumber
# 0 -0.922202  1.562879               0
#           X         Y  CentroidNumber
# 0 -0.944648  1.493904               0
#           X         Y  CentroidNumber
# 0 -0.878602  1.454361               0
#          X        Y  CentroidNumber
# 0 -0.89005  1.51459               0
#           X        Y  CentroidNumber
# 0 -0.810725  1.45463               0
#           X         Y  CentroidNumber
# 0 -0.772027  1.484418               0
#           X         Y  CentroidNumber
# 0 -0.749955  1.408426               0
#           X         Y  CentroidNumber
# 0 -0.706371  1.385526               0
#           X         Y  CentroidNumber
# 0 -0.666805  1.385259               0
#           X         Y  CentroidNumber
# 0 -0.625576  1.416784               0
#           X         Y  CentroidNumber
# 0 -0.598529  1.408813               0
#           X         Y  CentroidNumber
# 0 -0.555322  1.386484               0
#           X         Y  CentroidNumber
# 0 -0.543288  1.418122               0
#           X         Y  CentroidNumber
# 0 -0.551416  1.373583               0
#          X         Y  CentroidNumber
# 0 -0.50646  1.348577               0
#           X         Y  CentroidNumber
# 0 -0.455857  1.359988               0
#           X         Y  CentroidNumber
# 0 -0.422815  1.352822               0
#           X         Y  CentroidNumber
# 0 -0.326631  1.270081               0
#           X        Y  CentroidNumber
# 0 -0.353756  1.31028               0
#           X         Y  CentroidNumber
# 0 -0.309125  1.295361               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.259733  1.287242               0
#           X         Y  CentroidNumber
# 0 -0.265557  1.334499               0
#           X         Y  CentroidNumber
# 0 -0.224973  1.298077               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.177766  1.326573               0
#           X         Y  CentroidNumber
# 0  0.200086  1.303077               0
#           X        Y  CentroidNumber
# 0  0.230954  1.33499               0
#           X         Y  CentroidNumber
# 0  0.243249  1.392161               0
#           X         Y  CentroidNumber
# 0  0.284832  1.353936               0
#           X         Y  CentroidNumber
# 0  0.309461  1.355594               0
#           X         Y  CentroidNumber
# 0  0.314359  1.371512               0
#           X         Y  CentroidNumber
# 0  0.402381  1.345632               0
#           X         Y  CentroidNumber
# 0  0.404339  1.373143               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.442139  1.384874               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.630232  1.444353               0
#           X         Y  CentroidNumber
# 0  0.651293  1.412257               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X        Y  CentroidNumber
# 0  0.722277  1.45062               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.848797  1.468557               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  1.187329  1.953714               0
#           X         Y  CentroidNumber
# 0 -0.836111  5.055184               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.814741  4.964324               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.922965  4.948554               0
#           X         Y  CentroidNumber
# 0 -0.943191  4.933635               0
#           X         Y  CentroidNumber
# 0 -0.982103  4.885646               0
#           X         Y  CentroidNumber
# 0 -0.953192  4.891603               0
#           X         Y  CentroidNumber
# 0 -0.998259  4.850642               0
#           X         Y  CentroidNumber
# 0  1.332222  2.153387               0
#           X         Y  CentroidNumber
# 0  1.576138  2.229633               0
# 1 -0.967808  4.739483               1
#           X         Y  CentroidNumber
# 0  1.471211  2.258737               0
# 1 -1.126094  4.727682               1
#           X         Y  CentroidNumber
# 0  1.494583  2.275954               0
# 1 -1.110363  4.688828               1
#           X         Y  CentroidNumber
# 0  1.505528  2.266544               0
# 1 -1.142282  4.655013               1
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.180251  4.573668               0
#           X        Y  CentroidNumber
# 0 -1.115602  4.55991               0
#          X         Y  CentroidNumber
# 0 -1.14059  4.513538               0
#           X         Y  CentroidNumber
# 0 -1.102148  4.499691               0
#           X         Y  CentroidNumber
# 0  1.430685  2.435277               0
# 1 -1.190486  4.431879               1
#           X         Y  CentroidNumber
# 0 -1.111652  4.431231               0
#           X         Y  CentroidNumber
# 0 -1.117717  4.370191               0
#           X         Y  CentroidNumber
# 0  1.524346  2.599502               0
# 1 -1.179803  4.304303               1
#          X         Y  CentroidNumber
# 0 -1.16879  4.370332               0
#           X         Y  CentroidNumber
# 0  1.677142  2.682177               0
# 1 -1.169109  4.281062               1
#           X         Y  CentroidNumber
# 0  1.639968  2.685248               0
# 1 -1.233613  4.248312               1
#           X         Y  CentroidNumber
# 0  1.590556  2.678850               0
# 1 -1.185718  4.209568               1
#           X         Y  CentroidNumber
# 0  1.608230  2.705512               0
# 1 -1.206131  4.175091               1
#           X         Y  CentroidNumber
# 0 -1.475089  4.202247               0
#         X         Y  CentroidNumber
# 0 -1.3672  4.094964               0
#           X         Y  CentroidNumber
# 0 -1.263477  4.084787               0
#          X         Y  CentroidNumber
# 0 -1.17773  4.066047               0
#           X         Y  CentroidNumber
# 0 -1.534271  4.012035               0
#           X         Y  CentroidNumber
# 0 -1.232259  3.956736               0
#           X         Y  CentroidNumber
# 0 -1.479004  3.951349               0
#           X         Y  CentroidNumber
# 0 -1.435185  3.901003               0
#           X         Y  CentroidNumber
# 0 -1.446277  3.886506               0
#           X         Y  CentroidNumber
# 0 -1.439156  3.826589               0
#           X         Y  CentroidNumber
# 0 -1.621137  3.795241               0
#           X         Y  CentroidNumber
# 0 -1.570167  3.759362               0
#           X         Y  CentroidNumber
# 0 -1.641601  3.740488               0
#           X         Y  CentroidNumber
# 0 -1.691366  3.707551               0
#           X         Y  CentroidNumber
# 0 -1.551176  3.683657               0
#           X         Y  CentroidNumber
# 0 -1.515689  3.637097               0
#           X         Y  CentroidNumber
# 0 -1.624325  3.600776               0
#           X         Y  CentroidNumber
# 0 -1.621474  3.544611               0
#           X         Y  CentroidNumber
# 0 -1.635349  3.502166               0
#           X         Y  CentroidNumber
# 0 -1.606983  3.408681               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.408128  3.307911               0
# 1  1.665295  3.633733               1
#           X         Y  CentroidNumber
# 0 -1.305684  3.249597               0
#           X         Y  CentroidNumber
# 0 -1.461729  3.234382               0
# 1  1.682824  3.646080               1
#           X         Y  CentroidNumber
# 0 -1.527313  3.175253               0
# 1  1.708566  3.726893               1
#           X         Y  CentroidNumber
# 0 -1.542186  3.175225               0
#           X         Y  CentroidNumber
# 0 -1.385042  3.137241               0
#           X         Y  CentroidNumber
# 0 -1.361004  3.097271               0
#           X         Y  CentroidNumber
# 0 -1.437469  3.043083               0
# 1  1.820232  3.865556               1
#           X         Y  CentroidNumber
# 0 -1.472114  2.983677               0
# 1  1.825394  3.830937               1
#           X         Y  CentroidNumber
# 0 -1.497694  2.948683               0
# 1  1.762251  3.923019               1
#           X         Y  CentroidNumber
# 0 -1.523606  2.921307               0
# 1  1.804980  3.966041               1
#           X         Y  CentroidNumber
# 0 -1.492289  2.883300               0
# 1  1.791252  4.003683               1
#           X         Y  CentroidNumber
# 0 -1.538146  2.873433               0
# 1  1.787568  3.993276               1
#           X         Y  CentroidNumber
# 0 -1.648028  2.823786               0
# 1  1.801167  4.098838               1
#           X         Y  CentroidNumber
# 0 -1.528029  2.776371               0
# 1  1.874030  4.056901               1
#           X         Y  CentroidNumber
# 0 -1.508608  2.803300               0
# 1  1.795893  4.152003               1
#           X         Y  CentroidNumber
# 0 -1.461971  2.732970               0
# 1  1.817480  4.243301               1
#           X         Y  CentroidNumber
# 0 -1.485068  2.686913               0
# 1  1.863322  4.215606               1
#           X         Y  CentroidNumber
# 0 -1.538616  2.694352               0
# 1  1.867209  4.243511               1
#           X         Y  CentroidNumber
# 0 -1.508767  2.624517               0
# 1  1.835883  4.216252               1
#           X         Y  CentroidNumber
# 0 -1.556201  2.564535               0
# 1  1.719216  4.315860               1
#           X         Y  CentroidNumber
# 0 -1.550662  2.551054               0
# 1  1.812800  4.346552               1
#           X         Y  CentroidNumber
# 0 -1.628224  2.517301               0
# 1  1.774334  4.373736               1
#           X         Y  CentroidNumber
# 0 -1.562420  2.482608               0
# 1  1.824803  4.400034               1
#           X         Y  CentroidNumber
# 0 -1.505578  2.439081               0
#          X         Y  CentroidNumber
# 0 -1.44682  2.436688               0
#           X         Y  CentroidNumber
# 0 -1.399963  2.399190               0
# 1  1.684813  4.508465               1
#           X         Y  CentroidNumber
# 0 -1.346288  2.349160               0
# 1  1.403187  4.555543               1
#           X         Y  CentroidNumber
# 0 -1.429731  2.325823               0
# 1  1.717466  4.595884               1
#           X        Y  CentroidNumber
# 0 -1.360415  2.29298               0
#           X        Y  CentroidNumber
# 0 -1.269484  2.29427               0
#           X         Y  CentroidNumber
# 0 -1.306802  2.216383               0
#           X         Y  CentroidNumber
# 0 -1.328743  2.223453               0
#           X         Y  CentroidNumber
# 0 -1.302904  2.140749               0
# 1  1.560282  4.685760               1
#           X         Y  CentroidNumber
# 0 -1.283742  2.040540               0
# 1  1.700762  4.737063               1
#           X         Y  CentroidNumber
# 0 -1.290958  2.014091               0
# 1  1.656837  4.757227               1
#           X         Y  CentroidNumber
# 0 -1.286254  1.975875               0
# 1  1.628954  4.794059               1
#           X         Y  CentroidNumber
# 0 -1.260643  1.935225               0
# 1  1.369994  4.823491               1
#           X         Y  CentroidNumber
# 0 -1.256588  1.911581               0
# 1  1.324938  4.832102               1
#           X         Y  CentroidNumber
# 0 -1.253490  1.965091               0
# 1  1.282522  4.878516               1
#           X         Y  CentroidNumber
# 0 -1.244467  1.868019               0
# 1  1.310354  4.909478               1
#          X        Y  CentroidNumber
# 0 -1.24843  1.84623               0
#           X         Y  CentroidNumber
# 0 -1.198862  1.855097               0
# 1  1.226539  4.908677               1
#           X         Y  CentroidNumber
# 0 -1.185867  1.814624               0
#           X         Y  CentroidNumber
# 0 -1.123427  1.750648               0
# 1  1.210300  4.947841               1
#           X         Y  CentroidNumber
# 0 -1.122869  1.749696               0
#           X         Y  CentroidNumber
# 0 -1.102981  1.711215               0
#           X         Y  CentroidNumber
# 0 -1.031034  1.668797               0
#          X         Y  CentroidNumber
# 0 -1.02271  1.680131               0
#           X         Y  CentroidNumber
# 0 -0.969129  1.617208               0
#           X         Y  CentroidNumber
# 0 -0.967067  1.671347               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.920416  1.620129               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.873964  1.556311               0
#           X         Y  CentroidNumber
# 0 -0.841763  1.501599               0
#           X         Y  CentroidNumber
# 0 -0.843551  1.539368               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.740204  1.391699               0
#           X         Y  CentroidNumber
# 0 -0.716695  1.367509               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.695804  1.403722               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.618074  1.303886               0
#           X         Y  CentroidNumber
# 0 -0.591691  1.302112               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.501437  1.284753               0
#           X         Y  CentroidNumber
# 0 -0.469797  1.304312               0
#           X         Y  CentroidNumber
# 0 -0.418747  1.285458               0
#           X        Y  CentroidNumber
# 0 -0.391248  1.33922               0
#           X         Y  CentroidNumber
# 0 -0.349972  1.393852               0
#           X         Y  CentroidNumber
# 0 -0.321071  1.381824               0
#           X         Y  CentroidNumber
# 0 -0.280252  1.376135               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.206682  1.373201               0
#           X         Y  CentroidNumber
# 0  0.217704  1.364965               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.271565  1.400456               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.405298  1.526181               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.795934  1.735569               0
# 1 -0.936372  4.918288               1
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.036271  4.905342               0
#          X         Y  CentroidNumber
# 0 -1.11445  4.852931               0
#          X         Y  CentroidNumber
# 0 -1.09189  4.865904               0
#           X         Y  CentroidNumber
# 0 -1.081031  4.812805               0
#           X         Y  CentroidNumber
# 0 -1.097492  4.785397               0
#           X         Y  CentroidNumber
# 0 -1.150899  4.757336               0
#           X         Y  CentroidNumber
# 0 -1.078947  4.742665               0
#           X         Y  CentroidNumber
# 0 -1.039371  4.705085               0
#           X         Y  CentroidNumber
# 0 -1.092067  4.682714               0
#           X         Y  CentroidNumber
# 0 -1.079795  4.643465               0
#           X         Y  CentroidNumber
# 0 -1.353125  4.597706               0
#           X         Y  CentroidNumber
# 0 -1.170535  4.595786               0
#           X         Y  CentroidNumber
# 0 -1.309015  4.586562               0
#           X         Y  CentroidNumber
# 0 -1.310021  4.543365               0
#           X         Y  CentroidNumber
# 0 -1.247345  4.494837               0
#           X         Y  CentroidNumber
# 0 -1.368476  4.497817               0
#           X         Y  CentroidNumber
# 0 -1.593289  4.460563               0
#           X         Y  CentroidNumber
# 0 -1.192503  4.407571               0
#           X         Y  CentroidNumber
# 0  1.296158  2.354593               0
# 1 -1.220360  4.346980               1
#           X         Y  CentroidNumber
# 0 -1.354295  4.313664               0
#          X         Y  CentroidNumber
# 0 -1.53413  4.267767               0
#           X         Y  CentroidNumber
# 0 -1.449687  4.276455               0
#           X         Y  CentroidNumber
# 0  1.362859  2.518391               0
# 1 -1.342704  4.228930               1
#           X        Y  CentroidNumber
# 0 -1.456364  4.20538               0
#           X         Y  CentroidNumber
# 0 -1.330858  4.177188               0
#           X         Y  CentroidNumber
# 0 -1.541214  4.174488               0
#           X         Y  CentroidNumber
# 0 -1.440678  4.154783               0
#           X         Y  CentroidNumber
# 0 -1.443759  4.104337               0
#           X         Y  CentroidNumber
# 0 -1.383249  4.057745               0
#           X         Y  CentroidNumber
# 0 -1.540726  4.040908               0
#           X         Y  CentroidNumber
# 0 -1.471582  4.048746               0
#          X         Y  CentroidNumber
# 0 -1.55802  4.011704               0
#       X     Y  CentroidNumber
# 0  None  None               0
#          X         Y  CentroidNumber
# 0 -1.37277  3.896388               0
#           X         Y  CentroidNumber
# 0 -1.386441  3.853206               0
#           X         Y  CentroidNumber
# 0 -1.409084  3.825537               0
#           X        Y  CentroidNumber
# 0 -1.553223  3.81818               0
#           X         Y  CentroidNumber
# 0 -1.533159  3.771102               0
#           X        Y  CentroidNumber
# 0 -1.565752  3.72968               0
#          X         Y  CentroidNumber
# 0 -1.65392  3.684151               0
#           X         Y  CentroidNumber
# 0 -1.604151  3.693768               0
#           X         Y  CentroidNumber
# 0 -1.629187  3.621759               0
#           X         Y  CentroidNumber
# 0 -1.619638  3.619153               0
#           X         Y  CentroidNumber
# 0 -1.703995  3.569147               0
#           X         Y  CentroidNumber
# 0 -1.753953  3.562554               0
#           X         Y  CentroidNumber
# 0 -1.735572  3.529394               0
#           X         Y  CentroidNumber
# 0 -1.654932  3.477223               0
#           X         Y  CentroidNumber
# 0 -1.673099  3.402862               0
#           X         Y  CentroidNumber
# 0 -1.678346  3.383493               0
#           X         Y  CentroidNumber
# 0 -1.570776  3.316618               0
#           X         Y  CentroidNumber
# 0 -1.524143  3.302986               0
#           X         Y  CentroidNumber
# 0 -1.525059  3.269669               0
#           X         Y  CentroidNumber
# 0 -1.566294  3.210177               0
#           X         Y  CentroidNumber
# 0 -1.606149  3.203959               0
#           X         Y  CentroidNumber
# 0 -1.504197  3.208058               0
#           X         Y  CentroidNumber
# 0 -1.590956  3.167126               0
#           X         Y  CentroidNumber
# 0 -1.396529  3.119233               0
#           X         Y  CentroidNumber
# 0 -1.573668  3.125194               0
#           X        Y  CentroidNumber
# 0 -1.575734  3.06184               0
#           X         Y  CentroidNumber
# 0 -1.500852  3.053232               0
#          X         Y  CentroidNumber
# 0 -1.53844  3.003388               0
#           X         Y  CentroidNumber
# 0 -1.542776  2.938163               0
#           X         Y  CentroidNumber
# 0 -1.542595  2.883101               0
#           X        Y  CentroidNumber
# 0 -1.507082  2.83371               0
#           X         Y  CentroidNumber
# 0 -1.546757  2.871315               0
#           X         Y  CentroidNumber
# 0 -1.569575  2.830017               0
#           X         Y  CentroidNumber
# 0 -1.486817  2.778065               0
#           X         Y  CentroidNumber
# 0 -1.532972  2.732097               0
#           X        Y  CentroidNumber
# 0 -1.502725  2.71695               0
#           X         Y  CentroidNumber
# 0 -1.554747  2.671653               0
# 1  1.780796  4.140254               1
#           X         Y  CentroidNumber
# 0  1.726760  4.188446               0
# 1 -1.522521  2.675451               1
#           X         Y  CentroidNumber
# 0 -1.449728  2.581671               0
# 1  1.583175  4.227582               1
#           X         Y  CentroidNumber
# 0 -1.473076  2.595984               0
# 1  1.633921  4.277827               1
#           X         Y  CentroidNumber
# 0 -1.512869  2.551902               0
# 1  1.652919  4.335423               1
#           X         Y  CentroidNumber
# 0 -1.474156  2.495124               0
# 1  1.385797  4.360566               1
#           X         Y  CentroidNumber
# 0 -1.554702  2.453959               0
# 1  1.478186  4.359529               1
#           X         Y  CentroidNumber
# 0 -1.502839  2.424176               0
# 1  1.382889  4.413517               1
#           X         Y  CentroidNumber
# 0 -1.527481  2.406119               0
# 1  1.403959  4.467258               1
#           X         Y  CentroidNumber
# 0 -1.517850  2.356923               0
# 1  1.473522  4.397254               1
#           X         Y  CentroidNumber
# 0 -1.441516  2.340054               0
# 1  1.660733  4.472829               1
#           X         Y  CentroidNumber
# 0 -1.379336  2.294322               0
#           X         Y  CentroidNumber
# 0 -1.470547  2.285346               0
# 1  1.369216  4.512830               1
#           X         Y  CentroidNumber
# 0 -1.337651  2.222772               0
# 1  1.403274  4.581812               1
#           X         Y  CentroidNumber
# 0 -1.365934  2.189212               0
# 1  1.357786  4.591426               1
#           X         Y  CentroidNumber
# 0 -1.380845  2.183290               0
# 1  1.649221  4.649275               1
#           X         Y  CentroidNumber
# 0 -1.370816  2.123771               0
# 1  1.563048  4.674891               1
#           X         Y  CentroidNumber
# 0 -1.323248  2.065229               0
#           X        Y  CentroidNumber
# 0 -1.328493  2.06636               0
#           X         Y  CentroidNumber
# 0 -1.257602  2.003717               0
# 1  1.713172  4.719042               1
#          X         Y  CentroidNumber
# 0 -1.32376  1.972911               0
#           X        Y  CentroidNumber
# 0 -1.373767  1.94409               0
#           X         Y  CentroidNumber
# 0 -1.378673  1.883142               0
#         X         Y  CentroidNumber
# 0 -1.3866  1.849872               0
#           X        Y  CentroidNumber
# 0 -1.312088  1.83295               0
#           X         Y  CentroidNumber
# 0 -1.294074  1.767613               0
#           X         Y  CentroidNumber
# 0 -1.302099  1.800779               0
#           X         Y  CentroidNumber
# 0 -1.240226  1.771797               0
#           X         Y  CentroidNumber
# 0 -1.308567  1.771286               0
#           X         Y  CentroidNumber
# 0 -1.260236  1.721713               0
#          X         Y  CentroidNumber
# 0 -1.22383  1.650927               0
#           X         Y  CentroidNumber
# 0 -1.216896  1.636291               0
#           X         Y  CentroidNumber
# 0 -1.099483  1.596766               0
#           X         Y  CentroidNumber
# 0 -1.119704  1.597111               0
#           X         Y  CentroidNumber
# 0 -1.123548  1.569687               0
#           X         Y  CentroidNumber
# 0 -1.073279  1.571024               0
#           X         Y  CentroidNumber
# 0 -1.044998  1.528601               0
#           X        Y  CentroidNumber
# 0 -1.037024  1.47535               0
#          X         Y  CentroidNumber
# 0 -1.02533  1.527802               0
#           X         Y  CentroidNumber
# 0 -0.988003  1.476332               0
#           X         Y  CentroidNumber
# 0 -0.955875  1.434375               0
#           X         Y  CentroidNumber
# 0 -0.910556  1.435133               0
#           X         Y  CentroidNumber
# 0 -0.900672  1.452769               0
#           X         Y  CentroidNumber
# 0 -0.869021  1.405079               0
#           X         Y  CentroidNumber
# 0 -0.837172  1.378175               0
#          X         Y  CentroidNumber
# 0 -0.78272  1.314489               0
#           X         Y  CentroidNumber
# 0 -0.769106  1.295484               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X        Y  CentroidNumber
# 0 -0.703511  1.31178               0
#           X         Y  CentroidNumber
# 0 -0.675557  1.215312               0
#           X         Y  CentroidNumber
# 0 -0.668204  1.233788               0
#           X         Y  CentroidNumber
# 0 -0.634461  1.231783               0
#           X         Y  CentroidNumber
# 0 -0.562159  1.158104               0
#           X         Y  CentroidNumber
# 0 -0.565649  1.233122               0
#           X         Y  CentroidNumber
# 0 -0.490604  1.187779               0
#           X         Y  CentroidNumber
# 0 -0.469068  1.178783               0
#          X         Y  CentroidNumber
# 0 -0.44554  1.192825               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X        Y  CentroidNumber
# 0 -0.335528  1.25435               0
#           X         Y  CentroidNumber
# 0 -0.278018  1.218452               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.187639  1.249555               0
#           X         Y  CentroidNumber
# 0  0.220268  1.224537               0
#           X         Y  CentroidNumber
# 0  0.245369  1.263171               0
#           X         Y  CentroidNumber
# 0  0.277698  1.244709               0
#           X         Y  CentroidNumber
# 0  0.286279  1.267888               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.350242  1.322996               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.406337  1.308291               0
#           X         Y  CentroidNumber
# 0  0.420471  1.404243               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X        Y  CentroidNumber
# 0  0.557977  1.45361               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.671876  1.477198               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.733503  1.493857               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.799575  1.498606               0
#           X         Y  CentroidNumber
# 0  0.768872  1.556581               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.902854  4.974734               0
#           X         Y  CentroidNumber
# 0 -1.039941  4.934675               0
#           X         Y  CentroidNumber
# 0 -0.948018  4.949718               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.014642  4.873363               0
#           X         Y  CentroidNumber
# 0 -1.002679  4.877321               0
#           X         Y  CentroidNumber
# 0 -1.059619  4.854535               0
#          X         Y  CentroidNumber
# 0 -1.06832  4.780484               0
#           X         Y  CentroidNumber
# 0 -1.035699  4.772565               0
#           X         Y  CentroidNumber
# 0 -1.106474  4.745424               0
#           X         Y  CentroidNumber
# 0 -1.117212  4.734704               0
#           X         Y  CentroidNumber
# 0  1.296075  1.935062               0
# 1 -1.099024  4.687660               1
#           X         Y  CentroidNumber
# 0 -1.088189  4.627027               0
#           X         Y  CentroidNumber
# 0  1.311571  1.995598               0
#           X         Y  CentroidNumber
# 0 -1.168312  4.613789               0
#           X         Y  CentroidNumber
# 0 -1.147502  4.603346               0
#           X         Y  CentroidNumber
# 0 -1.422234  4.532193               0
#           X         Y  CentroidNumber
# 0 -1.421828  4.540547               0
#           X         Y  CentroidNumber
# 0 -1.215357  4.505814               0
#           X         Y  CentroidNumber
# 0 -1.164065  4.491263               0
#           X         Y  CentroidNumber
# 0 -1.457426  4.404971               0
#           X         Y  CentroidNumber
# 0 -1.130061  4.392495               0
#           X         Y  CentroidNumber
# 0  1.470142  2.286955               0
# 1 -1.538853  4.346728               1
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  1.766477  2.372528               0
# 1 -1.543435  4.281717               1
#           X         Y  CentroidNumber
# 0  1.742176  2.420694               0
# 1 -1.339687  4.262155               1
#           X         Y  CentroidNumber
# 0  1.647912  2.417780               0
# 1 -1.312058  4.181304               1
#           X        Y  CentroidNumber
# 0 -1.411541  4.18134               0
#           X         Y  CentroidNumber
# 0 -1.259889  4.129766               0
#           X         Y  CentroidNumber
# 0 -1.361973  4.123631               0
#           X         Y  CentroidNumber
# 0 -1.475003  4.088871               0
#           X         Y  CentroidNumber
# 0  1.724661  2.573703               0
# 1 -1.458328  4.058386               1
#           X         Y  CentroidNumber
# 0 -1.437114  4.076821               0
#           X         Y  CentroidNumber
# 0 -1.452708  4.001342               0
#           X         Y  CentroidNumber
# 0 -1.557075  3.959309               0
#           X         Y  CentroidNumber
# 0 -1.500975  3.918842               0
#           X         Y  CentroidNumber
# 0 -1.617809  3.866429               0
#           X         Y  CentroidNumber
# 0 -1.418867  3.841064               0
#           X         Y  CentroidNumber
# 0  1.613112  2.792417               0
# 1 -1.395713  3.813436               1
#          X         Y  CentroidNumber
# 0 -1.43035  3.777977               0
#           X         Y  CentroidNumber
# 0 -1.421335  3.745381               0
#           X         Y  CentroidNumber
# 0 -1.560394  3.672278               0
#           X         Y  CentroidNumber
# 0 -1.497806  3.699862               0
#           X        Y  CentroidNumber
# 0 -1.584736  3.62025               0
#           X         Y  CentroidNumber
# 0 -1.568813  3.568306               0
#           X         Y  CentroidNumber
# 0 -1.554437  3.545506               0
#           X         Y  CentroidNumber
# 0 -1.621185  3.453795               0
#           X         Y  CentroidNumber
# 0 -1.778794  3.459647               0
#           X        Y  CentroidNumber
# 0 -1.787603  3.40632               0
#           X         Y  CentroidNumber
# 0 -1.635096  3.378533               0
#           X         Y  CentroidNumber
# 0 -1.260577  3.305585               0
#           X         Y  CentroidNumber
# 0 -1.538077  3.319065               0
#          X        Y  CentroidNumber
# 0 -1.61956  3.28164               0
#          X         Y  CentroidNumber
# 0 -1.54346  3.219783               0
#           X         Y  CentroidNumber
# 0 -1.510121  3.202604               0
# 1  1.818237  3.445980               1
#           X         Y  CentroidNumber
# 0 -1.570232  3.173624               0
# 1  1.728438  3.490419               1
#           X         Y  CentroidNumber
# 0 -1.540653  3.155591               0
#           X         Y  CentroidNumber
# 0 -1.509980  3.083281               0
# 1  1.686668  3.508775               1
#           X         Y  CentroidNumber
# 0 -1.458164  3.035685               0
#           X         Y  CentroidNumber
# 0 -1.490855  3.004771               0
#           X         Y  CentroidNumber
# 0 -1.243948  2.976303               0
#           X         Y  CentroidNumber
# 0 -1.229702  2.905044               0
#          X         Y  CentroidNumber
# 0 -1.42368  2.878278               0
#           X         Y  CentroidNumber
# 0 -1.240209  2.847409               0
#           X         Y  CentroidNumber
# 0 -1.487885  2.854621               0
#           X         Y  CentroidNumber
# 0 -1.440913  2.833986               0
#           X         Y  CentroidNumber
# 0 -1.429363  2.791526               0
# 1  1.790701  3.885365               1
#           X         Y  CentroidNumber
# 0 -1.520823  2.780847               0
#           X         Y  CentroidNumber
# 0 -1.494868  2.697850               0
# 1  1.781239  3.986861               1
#           X         Y  CentroidNumber
# 0 -1.599877  2.678187               0
# 1  1.723692  4.000103               1
#          X         Y  CentroidNumber
# 0 -1.46452  2.693989               0
#           X         Y  CentroidNumber
# 0 -1.501654  2.632224               0
# 1  1.866669  4.048117               1
#           X         Y  CentroidNumber
# 0 -1.521401  2.604487               0
#           X         Y  CentroidNumber
# 0 -1.527973  2.573827               0
# 1  1.851514  4.143321               1
#           X         Y  CentroidNumber
# 0 -1.552806  2.561634               0
# 1  1.880297  4.202537               1
#           X         Y  CentroidNumber
# 0 -1.446146  2.541847               0
# 1  1.870282  4.255415               1
#           X         Y  CentroidNumber
# 0 -1.386619  2.523140               0
# 1  1.973694  4.279554               1
#           X         Y  CentroidNumber
# 0 -1.357655  2.448326               0
# ...
# 0  0.240503  1.418769               0
#           X         Y  CentroidNumber
# 0  0.256281  1.394138               0
#           X         Y  CentroidNumber
# 0  0.274557  1.468752               0
#           X         Y  CentroidNumber
# 0  0.308078  1.429996               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  0.343723  1.494314               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#          X         Y  CentroidNumber
# 0  0.73411  1.589974               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.915038  4.929345               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -0.961946  4.930849               0
#           X         Y  CentroidNumber
# 0 -1.054223  4.906236               0
#           X         Y  CentroidNumber
# 0 -1.016708  4.869699               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.071527  4.787083               0
#           X         Y  CentroidNumber
# 0 -1.037607  4.788674               0
#           X         Y  CentroidNumber
# 0 -1.077278  4.789851               0
#           X         Y  CentroidNumber
# 0 -1.107646  4.747761               0
#           X         Y  CentroidNumber
# 0  1.111590  2.255255               0
# 1 -1.183093  4.724559               1
#           X         Y  CentroidNumber
# 0  1.209356  2.111368               0
# 1 -1.118548  4.719644               1
#           X         Y  CentroidNumber
# 0 -1.125757  4.681592               0
#           X         Y  CentroidNumber
# 0 -1.133227  4.631894               0
#           X         Y  CentroidNumber
# 0 -1.153879  4.576945               0
#           X         Y  CentroidNumber
# 0 -1.172492  4.520491               0
#           X         Y  CentroidNumber
# 0 -1.437708  4.540887               0
#           X         Y  CentroidNumber
# 0 -1.409721  4.521561               0
#           X         Y  CentroidNumber
# 0 -1.403608  4.486745               0
#           X         Y  CentroidNumber
# 0 -1.409526  4.502017               0
#          X         Y  CentroidNumber
# 0 -1.51217  4.464463               0
#           X         Y  CentroidNumber
# 0 -1.593817  4.438652               0
#           X         Y  CentroidNumber
# 0 -1.542481  4.392695               0
#           X         Y  CentroidNumber
# 0 -1.579177  4.354998               0
#           X         Y  CentroidNumber
# 0 -1.575711  4.319493               0
#           X         Y  CentroidNumber
# 0 -1.542197  4.288053               0
#           X         Y  CentroidNumber
# 0 -1.546696  4.226691               0
#           X         Y  CentroidNumber
# 0 -1.472212  4.222065               0
#           X         Y  CentroidNumber
# 0 -1.497917  4.178951               0
#          X         Y  CentroidNumber
# 0 -1.43459  4.140723               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.406036  4.070831               0
#         X         Y  CentroidNumber
# 0 -1.4187  4.021983               0
#           X         Y  CentroidNumber
# 0 -1.559956  3.976758               0
#         X         Y  CentroidNumber
# 0 -1.4902  4.006962               0
#           X         Y  CentroidNumber
# 0 -1.329768  3.901838               0
#           X         Y  CentroidNumber
# 0 -1.413622  3.875881               0
#           X         Y  CentroidNumber
# 0 -1.557743  3.849587               0
#           X         Y  CentroidNumber
# 0 -1.470213  3.840706               0
#           X         Y  CentroidNumber
# 0 -1.495077  3.786708               0
#           X         Y  CentroidNumber
# 0 -1.546165  3.776994               0
#           X         Y  CentroidNumber
# 0 -1.612512  3.699369               0
#           X         Y  CentroidNumber
# 0 -1.598148  3.684185               0
#           X         Y  CentroidNumber
# 0 -1.598521  3.645529               0
#           X         Y  CentroidNumber
# 0 -1.581354  3.603611               0
#           X         Y  CentroidNumber
# 0 -1.710434  3.572295               0
#           X         Y  CentroidNumber
# 0 -1.674582  3.531469               0
#           X         Y  CentroidNumber
# 0 -1.684625  3.512118               0
#           X         Y  CentroidNumber
# 0 -1.703351  3.481076               0
#           X         Y  CentroidNumber
# 0 -1.710853  3.427817               0
#          X         Y  CentroidNumber
# 0 -1.70765  3.400282               0
#           X         Y  CentroidNumber
# 0 -1.668977  3.354978               0
#           X         Y  CentroidNumber
# 0 -1.691192  3.312848               0
#           X         Y  CentroidNumber
# 0 -1.577197  3.278005               0
#          X         Y  CentroidNumber
# 0 -1.64132  3.308362               0
#           X         Y  CentroidNumber
# 0 -1.545732  3.242405               0
#           X         Y  CentroidNumber
# 0 -1.572069  3.181789               0
#           X        Y  CentroidNumber
# 0 -1.569183  3.13713               0
#           X         Y  CentroidNumber
# 0 -1.593566  3.111683               0
#           X         Y  CentroidNumber
# 0 -1.525028  3.078765               0
#           X         Y  CentroidNumber
# 0 -1.477768  3.004578               0
#           X         Y  CentroidNumber
# 0 -1.558447  3.047019               0
#           X        Y  CentroidNumber
# 0 -1.633653  2.98687               0
#           X         Y  CentroidNumber
# 0 -1.608781  2.947819               0
#           X         Y  CentroidNumber
# 0 -1.454497  2.887219               0
#           X         Y  CentroidNumber
# 0 -1.508379  2.833674               0
#           X        Y  CentroidNumber
# 0 -1.595119  2.80929               0
#           X         Y  CentroidNumber
# 0 -1.575953  2.798885               0
# 1  1.774646  3.931928               1
#           X         Y  CentroidNumber
# 0 -1.568369  2.762746               0
#           X         Y  CentroidNumber
# 0  1.726625  4.003635               0
# 1 -1.472734  2.716367               1
#           X         Y  CentroidNumber
# 0 -1.508660  2.659340               0
# 1  1.750808  4.007742               1
#           X         Y  CentroidNumber
# 0 -1.520783  2.666950               0
# 1  1.809594  4.083217               1
#           X         Y  CentroidNumber
# 0 -1.541897  2.613131               0
# 1  1.692586  4.077016               1
#           X         Y  CentroidNumber
# 0 -1.552487  2.569200               0
# 1  1.727487  4.105392               1
#           X         Y  CentroidNumber
# 0 -1.564968  2.519814               0
#           X         Y  CentroidNumber
# 0 -1.521444  2.484764               0
#           X         Y  CentroidNumber
# 0 -1.545504  2.490962               0
#          X         Y  CentroidNumber
# 0 -1.47899  2.422598               0
# 1  1.74542  4.264134               1
#           X         Y  CentroidNumber
# 0 -1.527137  2.417218               0
# 1  1.671549  4.307925               1
#           X         Y  CentroidNumber
# 0 -1.498536  2.364413               0
# 1  1.355240  4.268934               1
#           X         Y  CentroidNumber
# 0 -1.515879  2.399357               0
# 1  1.646691  4.343455               1
#           X         Y  CentroidNumber
# 0 -1.507077  2.388147               0
# 1  1.452871  4.407005               1
#           X        Y  CentroidNumber
# 0 -1.534445  2.29184               0
#           X         Y  CentroidNumber
# 0 -1.479289  2.229882               0
# 1  1.773785  4.420995               1
#          X         Y  CentroidNumber
# 0 -1.43110  2.163335               0
# 1  1.36866  4.492812               1
#           X         Y  CentroidNumber
# 0 -1.475104  2.162726               0
# 1  1.283418  4.482047               1
#           X         Y  CentroidNumber
# 0 -1.391855  2.146356               0
# 1  1.634436  4.488031               1
#           X         Y  CentroidNumber
# 0 -1.422845  2.135034               0
# 1  1.303300  4.558629               1
#           X         Y  CentroidNumber
# 0 -1.406426  2.054544               0
# 1  1.315308  4.562921               1
#           X         Y  CentroidNumber
# 0 -1.436555  2.031241               0
# 1  1.301461  4.598651               1
#           X         Y  CentroidNumber
# 0 -1.414654  2.044909               0
# 1  1.286295  4.641006               1
#           X         Y  CentroidNumber
# 0 -1.362407  1.990323               0
# 1  1.360416  4.667063               1
#           X         Y  CentroidNumber
# 0 -1.269316  1.927053               0
# 1  1.343337  4.693748               1
#           X         Y  CentroidNumber
# 0 -1.349219  1.947532               0
# 1  1.524618  4.755724               1
#           X         Y  CentroidNumber
# 0 -1.391116  1.907959               0
#           X         Y  CentroidNumber
# 0 -1.334194  1.877992               0
# 1  1.305632  4.788680               1
#           X         Y  CentroidNumber
# 0 -1.296776  1.821771               0
# 1  1.294581  4.844175               1
#           X         Y  CentroidNumber
# 0 -1.279962  1.778531               0
# 1  1.681754  4.837654               1
#           X         Y  CentroidNumber
# 0 -1.298959  1.748197               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0 -1.383724  1.697155               0
#           X         Y  CentroidNumber
# 0 -1.257396  1.690007               0
# 1  1.267524  4.833947               1
#           X         Y  CentroidNumber
# 0 -1.232725  1.653072               0
# 1  1.294008  4.902668               1
#           X         Y  CentroidNumber
# 0 -1.228887  1.594607               0
#           X         Y  CentroidNumber
# 0 -1.244923  1.619342               0
#           X        Y  CentroidNumber
# 0 -1.223198  1.61753               0
#           X         Y  CentroidNumber
# 0 -1.240888  1.577791               0
#          X         Y  CentroidNumber
# 0 -1.18365  1.532565               0
#           X         Y  CentroidNumber
# 0 -1.199551  1.569503               0
#           X         Y  CentroidNumber
# 0 -1.168144  1.551373               0
#           X         Y  CentroidNumber
# 0 -1.182566  1.550943               0
#           X         Y  CentroidNumber
# 0 -1.160266  1.518481               0
#           X         Y  CentroidNumber
# 0 -1.115909  1.491367               0
#           X         Y  CentroidNumber
# 0 -1.139939  1.502324               0
#           X         Y  CentroidNumber
# 0 -1.121044  1.487753               0
#           X         Y  CentroidNumber
# 0 -1.094348  1.480985               0
#           X       Y  CentroidNumber
# 0 -1.103371  1.4375               0
#           X         Y  CentroidNumber
# 0 -1.092384  1.441083               0
# 1  1.089835  5.107096               1
#          X         Y  CentroidNumber
# 0 -1.09515  1.430828               0
#           X         Y  CentroidNumber
# 0 -1.098361  1.422951               0
#           X         Y  CentroidNumber
# 0 -1.070711  1.395559               0
#           X         Y  CentroidNumber
# 0 -1.073431  1.423768               0
# 1  1.144958  5.057574               1
#           X         Y  CentroidNumber
# 0 -1.068965  1.346886               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  1.118977  5.071012               0
#       X     Y  CentroidNumber
# 0  None  None               0
#           X         Y  CentroidNumber
# 0  1.132146  5.069355               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0
#       X     Y  CentroidNumber
# 0  None  None               0

# %%
#plot first frame of two people walking after runnining throug algorithm
plt.figure()
cluster = clusterList[0]
plt.scatter(cluster['X'], cluster['Y'])
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)

# %% [markdown]
# #### Unit Tests

# %%
#dfs unit test and overall algorithm test set 
posX = np.array([2,2.1,2.2,2.1,2.2,2.2,5,5.1,5,4,5])
posY = np.array([4,4,4,3.8,3.9,3.95,2,2,2.1,4,5])

# %%
#unit test to check vertex and edge generation
posX = np.array([1,1,1,2,3])
posY = np.array([4,3,2,4,4])

# %%
#vertex dataframe
vertexID = np.arange(len(posX))
vertexDf = pd.DataFrame({'VertexID':vertexID, 'X':posX, 'Y':posY})
print()
#minimum number of points to qualify as a person
if len(vertexDf.values) >= minClusterSize: #do you even have one cluster
    #preallocate edgeMatrix
    #edges are denoted by their respective weights
    #undirected graph with constraint that two nodes can only be connected by one edge
    edgeMatrix = np.zeros((len(posX), len(posY)))
    #vertices are saved as np arrays
    #evaluate edge Matrix and create graph
    for rowIndex in range(0, edgeMatrix.shape[0]):
        for colIndex in range(0, edgeMatrix.shape[1]):
            if rowIndex == colIndex:
                continue #diagonal element
            elif edgeMatrix[rowIndex, colIndex] != 0:
                continue #element already filled
            else:
                pointA = (vertexDf.values[rowIndex])[1:] #extract x y position disregarding the vertexID
                pointB = (vertexDf.values[colIndex])[1:] #extract x y position disregarding the vertexID
                length = euclidean(pointA, pointB)
                #fill elements
                edgeMatrix[rowIndex,colIndex] = length
                edgeMatrix[colIndex, rowIndex] = length

    #weight based reduction of graph/remove edges by replacing edge weight by np.NaN
    weightMask = np.logical_or(np.greater(edgeMatrix,weightThreshold), np.equal(edgeMatrix, 0))
    edgeMatrix[weightMask] = np.NaN

    #perform DFS to find connected components
    componentsList = list() #list of components
    vertexList = list() #used to hold vertices that have been considered
    for vertex in vertexDf['VertexID']:
        if vertex not in vertexList:
            visitedNodes = recursiveDfs(vertexDf, edgeMatrix, vertex, visited=None)
            componentsList.append(list(visitedNodes))
            for vertex in visitedNodes:
                if vertex not in vertexList:
                    vertexList.append(vertex)
                    
    #use minimum cluster size to remove bad cluster matches
    #and extract clusters
    clusterList = list()
    for cluster in componentsList:
        if len(cluster) >= minClusterSize:
            pointCluster = vertexDf.loc[np.array(cluster)]
            clusterList.append(pointCluster)
            
else:
    print('NOT ENOUGH POINTS')

# %%
# Out:
#    VertexID    X     Y
# 0         0  2.0  4.00
# 1         1  2.1  4.00
# 2         2  2.2  4.00
# 3         3  2.1  3.80
# 4         4  2.2  3.90
# 5         5  2.2  3.95

# %%
def recursiveDfs(vertexDf, edgeMatrix, startNode, visited):
    
    if visited is None:
        #very first recursive iteration
        visited = set()
    visited.add(startNode)
    
    neighboursOfStart = vertexDf['VertexID'].values[np.logical_not(np.isnan(edgeMatrix[int(startNode), :]))]
    for nextNode in neighboursOfStart:
        if nextNode not in visited:
            visited = recursiveDfs(vertexDf, edgeMatrix, nextNode, visited)
    return visited

# %%
#plot the first frame of two people walking
plt.figure()
plt.scatter(posX, posY)
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)

# %%
#plot first frame of two people walking after runnining throug algorithm
plt.figure()
for cluster in clusterList:
    plt.scatter(cluster['X'], cluster['Y'])
plt.xlim(-6, 6)
plt.ylim(0,6)
# Out:
# (0, 6)
