# %% [markdown]
# # Discrete Kalman Filter

# %%
import numpy as np
import pandas as pd
from scipy.linalg import expm

# %% [markdown]
# ### Helper Functions

# %%
def predictStep(x, A):
    xPred = np.matmul(A,x)
    return xPred

# %%
def innovationStep(xPred,z, H):
    innovation = np.subtract(z, np.matmul(H, xPred)) #innovation
    return innovation

# %%
def UpdateStep(xPred, nu, K):
    xNew = np.add(xPred, np.matmul(K, innovation))
    return xNew

# %%
def dataAssociation(rThetaMeasurement, filteredCentroidPolarFrames):
    #predict
    previousCentroids = filteredCentroidPolarFrames[-1]
    xPredAll = np.array([])
    for centroidIndex in list(previousCentroids['CentroidNumber']):
        xPrev = np.expand_dims(previousCentroids.loc[centroidIndex][:-1].values, axis=1)
        xPred = predictStep(xPrev, A)
        if len(xPredAll) == 0:
            xPredAll = xPred
        else:
            xPredAll = np.hstack((xPredAll, xPred))

    xPredAll = np.transpose(xPredAll) #keep consistent with other dataframes
    xPredDf = pd.DataFrame(xPredAll)
    xPredDf.columns = ['PredictedRange', 'PredictedDoppler', 'PredictedTheta', 'PredictedAngularVelocity']
    xPredDf['CentroidNumber'] = pd.Series(np.arange(xPredDf.shape[0]))

    #data associate
    distanceMatrix = np.eye(xPredDf.shape[0], rThetaMeasurement.shape[0])
    #create distance matrix
    for centroidIndex in xPredDf['CentroidNumber']:
        #access prev centroid information
        prevCentroidInfo = xPredDf.loc[centroidIndex]
        #compare against measurement centroid stats and find distances
        for centroidNumber in rThetaMeasurement['CentroidNumber']:
            #access measured centroid information
            measurementCentroidInfo = rThetaMeasurement.loc[centroidNumber]
            #find distances between measured and predicted centroids
            length = np.sqrt((prevCentroidInfo.PredictedRange**2) + (measurementCentroidInfo.R ** 2) - \
            (2*measurementCentroidInfo.R*prevCentroidInfo.PredictedRange*np.cos((prevCentroidInfo.PredictedTheta - measurementCentroidInfo.Theta))))
            #fill in distance matrix
            distanceMatrix[centroidIndex, centroidNumber] = length
    #global association
    correctAssociationMatrix = np.array([])
    #loop as many times as needed
    for loopIterator in range(0, min(max(xPredDf['CentroidNumber']),max(rThetaMeasurement['CentroidNumber']))+1) :
        #find minimum distance 
        predictedCentroidNumber, measuredCentroidNumber = (np.where(distanceMatrix == np.min(distanceMatrix))[0][0], \
                                                           np.where(distanceMatrix == np.min(distanceMatrix))[1][0])
        if len(correctAssociationMatrix) == 0:
            correctAssociationMatrix = np.array([rThetaMeasurement.loc[measuredCentroidNumber].R,\
                                                        rThetaMeasurement.loc[measuredCentroidNumber].Theta,predictedCentroidNumber])
        else:
            correctAssociationMatrix = np.vstack((correctAssociationMatrix,\
                                                  np.array([rThetaMeasurement.loc[measuredCentroidNumber].R,\
                                                            rThetaMeasurement.loc[measuredCentroidNumber].Theta,predictedCentroidNumber])))

        #fill in with Inf where the centroid has been associated
        distanceMatrix[predictedCentroidNumber, :] = np.Inf
   
    #create associated df
    try:
        correctAssociationMatrix.shape[1]
        associatedDf = pd.DataFrame({'MeasuredRange':correctAssociationMatrix[:,0], 
                            'MeasuredTheta': correctAssociationMatrix[:,1],
                            'CentroidNumber': correctAssociationMatrix[:,2]})
    except:
        associatedDf = pd.DataFrame({'MeasuredRange':correctAssociationMatrix[0], 
                                'MeasuredTheta': correctAssociationMatrix[1],
                                'CentroidNumber': correctAssociationMatrix[2]}, index=range(1))

    #measurement has more centroids than associated
    if associatedDf.shape[0] < rThetaMeasurement.shape[0]:
        print('MORE')
        #add those extra centoids 
        for centroidIndex in range(0,rThetaMeasurement.shape[0]):
            measurement = rThetaMeasurement.loc[centroidIndex]
            if measurement.R not in list(associatedDf['MeasuredRange']):
                measurement = {'MeasuredRange': measurement.R, 'MeasuredTheta':measurement.Theta, 'CentroidNumber': max(associatedDf['CentroidNumber']+1)}
                measurement = pd.DataFrame(data=measurement, index=range(1))
                associatedDf = pd.concat([associatedDf,measurement], axis=0, ignore_index = True)                       

    #measurement has less centroids than predicted - add the predicted value of the unassociated centroid into the associatedDf
    if not((np.isinf(distanceMatrix)).all()):
        print('LESS')
        #add predicted value of unassociated centroid to the dataframe
        np.isfinite(distanceMatrix[:,0])
        for centroidIndex in range(0,xPredDf.shape[0]):
            predicted = xPredDf.loc[centroidIndex]
            if predicted.CentroidNumber not in list(associatedDf['CentroidNumber']):
                predicted = {'MeasuredRange': predicted.Range, 'MeasuredTheta':predicted.Theta, 'CentroidNumber': predicted.CentroidNumber}
                predicted = pd.DataFrame(data=predicted, index=range(1))
                associatedDf = pd.concat([associatedDf,predicted], axis=0, ignore_index = True)    
    return associatedDf, xPredDf

# %%
#convert x,y to r,theta
def convertCartesianToPolar(cartesianMeasurementCentroidDf):
    measurementR = np.sqrt(np.square(cartesianMeasurementCentroidDf['X']) + np.square(cartesianMeasurementCentroidDf['Y']))
    measurementTheta = np.arctan(cartesianMeasurementCentroidDf['Y']/cartesianMeasurementCentroidDf['X'])
    polarCentroidDf = pd.DataFrame({'CentroidNumber':cartesianMeasurementCentroidDf['CentroidNumber'], 
                                   'R': measurementR,
                                   'Theta': measurementTheta})
    return polarCentroidDf

# %% [markdown]
# ### Main Code

# %%
#initialize variables
deltaT = 50*10**-3 #50ms

#system matrix
A = np.array([
    [1, deltaT, 0,0],
    [0,1,0,0],
    [0,0,1,deltaT],
    [0,0,0,1]
])
#state transition matrix
F = expm(A*deltaT)
#output matrix
H = np.array([[1,0,0,0],
              [0,0,1,0]])
#covariance matrices
Q = np.eye(4)
R = np.ones(2).reshape(-1,1)
Pc = np.eye(4)

Pd = np.add(np.matmul(np.matmul(A,Pc), np.transpose(A)), Q) #prediction covariance
S = np.add(R, np.matmul(np.matmul(H, Pd), np.transpose(H))) #innovation covariance
K = np.matmul(Pd, np.matmul(np.transpose(H), np.linalg.inv(S))) #kalman gain
Pupdate = np.subtract(Pd, np.matmul(np.matmul(K, S), np.transpose(K))) #update covariance

# %%
#read in measurements from csv
rawCentroidData = pd.read_csv('OnePersonWalkingCentroidData.csv', header=None)
#find headers and frames within headers
#each header has the structure X, Y, CentroidNumber
#below each header is the frame data
centroidFramesCartesianMeasurement = list()
headerFound = False
for rowIndex in range(0, rawCentroidData.shape[0]):
    row = rawCentroidData.loc[rowIndex]
    if row[0] == 'X' and row[1] == 'Y' and row[2] == 'CentroidNumber':
        if headerFound: 
            #actual data was found last frame and this frame actual data is found again
            #past frame ended so add to list
            centroidFramesCartesianMeasurement.append(frame)
            frame = pd.DataFrame([])
        else:
            #header found
            headerFound = True
            frame = pd.DataFrame([])
        #data should be following
    elif headerFound:
        if np.isnan(np.float(row[0])) and np.isnan(np.float(row[1])):
            #empty row 
            centroidFramesCartesianMeasurement.append(frame)
            headerFound = False
            #only time its going to be NaN if the frame is completely empty
        else:
            #actual data
            X = np.float(row[0])
            Y = np.float(row[1])
            CentroidNumber = int(row[2])
            if len(frame) == 0:
                frame = pd.DataFrame({'X':X, 'Y':Y, 'CentroidNumber':CentroidNumber}, index=range(1))
            else:
                data = pd.DataFrame({'X':X, 'Y':Y, 'CentroidNumber':CentroidNumber}, index=range(1))
                frame = pd.concat([frame,data])

# %%
filteredCentroidPolarFrames = list()

#load in frames
for centroidFrame in centroidFramesCartesianMeasurement:
    filteredPolarFrame = np.array([])
    if len(centroidFrame) > 0:
        rThetaMeasurement = convertCartesianToPolar(centroidFrame)

        if len(filteredCentroidPolarFrames) == 0: #first iteration of the kalman filter
            polarCentroidFrameMeasurement = convertCartesianToPolar(centroidFrame)
            for centroid in polarCentroidFrameMeasurement['CentroidNumber']:
                x = np.expand_dims(np.array([0,0,0,0]), axis=1) #initialise 
                xPred = predictStep(x, A)
                measurement = np.expand_dims(polarCentroidFrameMeasurement.values[int(centroid)][1:], axis=1)
                innovation = innovationStep(xPred, measurement, H)
                xUpdate = UpdateStep(xPred, innovation, K)
                if len(filteredPolarFrame) == 0:
                    filteredPolarFrame = xUpdate
                else:
                    filteredPolarFrame = np.hstack((filteredPolarFrame,xUpdate))
        else:

            associatedDf, xPredDf = dataAssociation(rThetaMeasurement, filteredCentroidPolarFrames)
            overallDf = pd.merge(associatedDf, xPredDf, on='CentroidNumber', how='inner')
            for index in range(0 , overallDf.shape[0]):
                centroidData = overallDf.loc[index]
                measurement = np.expand_dims(np.array([centroidData.MeasuredRange, centroidData.MeasuredTheta]), axis=1)
                xPred = np.expand_dims(np.array([centroidData.PredictedRange, centroidData.PredictedDoppler,centroidData.PredictedTheta, centroidData.PredictedAngularVelocity]), axis=1)
                innovation = innovationStep(xPred, measurement, H)
                xUpdate = UpdateStep(xPred, innovation, K)
                if len(filteredPolarFrame) == 0:
                    filteredPolarFrame = xUpdate
                else:
                    filteredPolarFrame = np.hstack((filteredPolarFrame,xUpdate))
    elif len(centroidFrame) == 0 and len(filteredCentroidPolarFrames) != 0:
        #all centroids dissapear from frame
        previousCentroids = filteredCentroidPolarFrames[-1]
        xPredAll = np.array([])
        for centroidIndex in list(previousCentroids['CentroidNumber']):
            xPrev = np.expand_dims(previousCentroids.loc[centroidIndex][:-1].values, axis=1)
            xPred = predictStep(xPrev, A)
            if len(xPredAll) == 0:
                xPredAll = xPred
            else:
                xPredAll = np.hstack((xPredAll, xPred))
        xUpdateAll = xPredAll #for understanding purposes
        filteredPolarFrame = xUpdateAll #for understanding purposes
    else:
        continue
        
    filteredPolarDf = pd.DataFrame(np.transpose(filteredPolarFrame))
    filteredPolarDf.columns = ['Filtered Range', 'Filtered Doppler', 'Filtered Theta', 'Filtered Angular Velocity']
    filteredPolarDf['CentroidNumber'] = pd.Series(np.arange(filteredPolarDf.shape[0]))
    filteredCentroidPolarFrames.append(filteredPolarDf)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.769378  4.760197               0
#           X         Y  CentroidNumber
# 0  1.750144  4.747785               0
#           X         Y  CentroidNumber
# 0  1.844464  4.747338               0
#           X         Y  CentroidNumber
# 0  1.737365  4.776371               0
#           X         Y  CentroidNumber
# 0  1.785549  4.812852               0
#           X         Y  CentroidNumber
# 0  1.736776  4.794367               0
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0  1.68846  4.696127               0
#           X         Y  CentroidNumber
# 0  1.624926  4.706563               0
#           X         Y  CentroidNumber
# 0  1.649368  4.708099               0
#          X         Y  CentroidNumber
# 0  1.63623  4.663597               0
#           X        Y  CentroidNumber
# 0  1.650841  4.66136               0
#           X       Y  CentroidNumber
# 0  1.583397  4.6453               0
#           X         Y  CentroidNumber
# 0  1.592029  4.617378               0
#           X        Y  CentroidNumber
# 0  1.636065  4.61781               0
#           X        Y  CentroidNumber
# 0  1.677777  4.58198               0
#           X         Y  CentroidNumber
# 0  1.683423  4.576877               0
#           X         Y  CentroidNumber
# 0  1.683986  4.562917               0
#           X         Y  CentroidNumber
# 0  1.732743  4.592499               0
#           X         Y  CentroidNumber
# 0  1.690332  4.582152               0
#           X         Y  CentroidNumber
# 0  1.616729  4.605038               0
#           X         Y  CentroidNumber
# 0  1.551335  4.633238               0
#          X         Y  CentroidNumber
# 0  1.55956  4.589163               0
#           X       Y  CentroidNumber
# 0  1.627216  4.5817               0
#           X       Y  CentroidNumber
# 0  1.611933  4.6088               0
#           X         Y  CentroidNumber
# 0  1.540444  4.609722               0
#           X         Y  CentroidNumber
# 0  1.387637  4.611291               0
#           X         Y  CentroidNumber
# 0  1.387912  4.558172               0
#           X         Y  CentroidNumber
# 0  1.358979  4.525238               0
#           X        Y  CentroidNumber
# 0  1.528812  4.53834               0
#           X         Y  CentroidNumber
# 0  1.281483  4.568934               0
#           X         Y  CentroidNumber
# 0  1.264265  4.570716               0
#           X         Y  CentroidNumber
# 0  1.290398  4.544021               0
#           X         Y  CentroidNumber
# 0  1.496531  4.558238               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.572732  4.558874               0
#           X         Y  CentroidNumber
# 0  1.296301  4.553336               0
#           X         Y  CentroidNumber
# 0  1.479988  4.497794               0
#          X         Y  CentroidNumber
# 0  1.37706  4.497307               0
#           X         Y  CentroidNumber
# 0  1.571325  4.451835               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.374267  4.499122               0
#           X         Y  CentroidNumber
# 0  1.557488  4.423675               0
#          X         Y  CentroidNumber
# 0  1.56989  4.526289               0
#           X         Y  CentroidNumber
# 0  1.435296  4.473319               0
#           X         Y  CentroidNumber
# 0  1.418916  4.388583               0
#           X        Y  CentroidNumber
# 0  1.338281  4.47524               0
#           X         Y  CentroidNumber
# 0  1.340772  4.523802               0
#           X         Y  CentroidNumber
# 0  1.326642  4.528588               0
#           X         Y  CentroidNumber
# 0  1.614513  4.535528               0
#          X         Y  CentroidNumber
# 0  1.62238  4.571576               0
#           X         Y  CentroidNumber
# 0  1.624625  4.567066               0
#           X        Y  CentroidNumber
# 0  1.652284  4.58718               0
#           X         Y  CentroidNumber
# 0  1.403852  4.597689               0
#           X         Y  CentroidNumber
# 0  1.337226  4.583232               0
#           X        Y  CentroidNumber
# 0  1.332639  4.61325               0
#           X         Y  CentroidNumber
# 0  1.424575  4.570259               0
#           X         Y  CentroidNumber
# 0  1.353217  4.556799               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.538813  4.585078               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0  1.418379  4.60393               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.558087  4.560924               0
#           X         Y  CentroidNumber
# 0  1.343941  4.504451               0
#           X         Y  CentroidNumber
# 0  1.208417  4.582918               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.619445  4.501517               0
#           X         Y  CentroidNumber
# 0  1.600092  4.520053               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.657742  4.457282               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.181151  4.412992               0
#           X         Y  CentroidNumber
# 0  1.201999  4.389468               0
#           X         Y  CentroidNumber
# 0  1.337949  4.467281               0
#          X         Y  CentroidNumber
# 0  1.59655  4.441648               0
#           X         Y  CentroidNumber
# 0  1.282845  4.408748               0
#           X         Y  CentroidNumber
# 0  1.549093  4.415764               0
#          X        Y  CentroidNumber
# 0  1.59463  4.38282               0
#           X         Y  CentroidNumber
# 0  1.247154  4.337234               0
#           X         Y  CentroidNumber
# 0  1.590038  4.365002               0
#           X         Y  CentroidNumber
# 0  1.705722  4.348579               0
#           X         Y  CentroidNumber
# 0  1.276406  4.269841               0
#           X         Y  CentroidNumber
# 0  1.233736  4.163023               0
#           X         Y  CentroidNumber
# 0  1.686814  4.301978               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.608515  4.257301               0
#           X         Y  CentroidNumber
# 0  1.617348  4.216095               0
#           X        Y  CentroidNumber
# 0  1.682912  4.20225               0
#           X         Y  CentroidNumber
# 0  1.700549  4.149177               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.790479  4.084643               0
#           X         Y  CentroidNumber
# 0  1.713365  4.109717               0
#          X         Y  CentroidNumber
# 0  1.72098  4.032622               0
#           X         Y  CentroidNumber
# 0  1.699595  4.011545               0
#           X         Y  CentroidNumber
# 0  1.661326  3.960412               0
#          X         Y  CentroidNumber
# 0  1.65817  3.952875               0
#           X         Y  CentroidNumber
# 0  1.742992  3.931432               0
#           X         Y  CentroidNumber
# 0  1.730493  3.907943               0
#           X         Y  CentroidNumber
# 0  1.580557  3.862986               0
#           X         Y  CentroidNumber
# 0  1.655002  3.809921               0
#           X         Y  CentroidNumber
# 0  1.499336  3.787303               0
#           X         Y  CentroidNumber
# 0  1.354853  3.719833               0
#          X        Y  CentroidNumber
# 0  1.37777  3.70275               0
#           X         Y  CentroidNumber
# 0  1.342983  3.634346               0
#           X         Y  CentroidNumber
# 0  1.410673  3.621954               0
#           X         Y  CentroidNumber
# 0  1.342365  3.554876               0
#           X         Y  CentroidNumber
# 0  1.527674  3.566828               0
#           X         Y  CentroidNumber
# 0  1.530078  3.543039               0
#          X         Y  CentroidNumber
# 0  1.53805  3.469125               0
#           X         Y  CentroidNumber
# 0  1.435643  3.431037               0
#           X         Y  CentroidNumber
# 0  1.468868  3.413247               0
#           X         Y  CentroidNumber
# 0  1.500419  3.366833               0
#          X        Y  CentroidNumber
# 0  1.51008  3.32645               0
#           X         Y  CentroidNumber
# 0  1.372929  3.287948               0
#           X         Y  CentroidNumber
# 0  1.604963  3.265956               0
#          X         Y  CentroidNumber
# 0  1.55946  3.227853               0
#           X         Y  CentroidNumber
# 0  1.509198  3.190735               0
#           X         Y  CentroidNumber
# 0  1.532703  3.178862               0
#          X         Y  CentroidNumber
# 0  1.51994  3.132198               0
#           X         Y  CentroidNumber
# 0  1.532723  3.120461               0
#           X         Y  CentroidNumber
# 0  1.486656  3.023268               0
#           X         Y  CentroidNumber
# 0  1.454615  3.022851               0
#           X         Y  CentroidNumber
# 0  1.429147  2.960829               0
#           X         Y  CentroidNumber
# 0  1.478552  2.955868               0
#           X         Y  CentroidNumber
# 0  1.470597  2.907132               0
#           X         Y  CentroidNumber
# 0  1.452613  2.909519               0
#          X         Y  CentroidNumber
# 0  1.48619  2.879843               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.482053  2.830279               0
#           X         Y  CentroidNumber
# 0  1.451711  2.792238               0
#           X         Y  CentroidNumber
# 0  1.423145  2.730329               0
#           X         Y  CentroidNumber
# 0  1.423023  2.730171               0
#           X         Y  CentroidNumber
# 0  1.260406  2.604231               0
#          X         Y  CentroidNumber
# 0  1.30536  2.589392               0
#           X         Y  CentroidNumber
# 0  1.226265  2.538009               0
#           X         Y  CentroidNumber
# 0  1.234628  2.465481               0
#           X         Y  CentroidNumber
# 0  1.329208  2.493175               0
#           X         Y  CentroidNumber
# 0  1.266153  2.440529               0
#           X         Y  CentroidNumber
# 0  1.294234  2.343812               0
#           X         Y  CentroidNumber
# 0  1.352162  2.375366               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.314761  2.283279               0
#           X         Y  CentroidNumber
# 0  1.217984  2.225771               0
#           X         Y  CentroidNumber
# 0  1.267322  2.190026               0
#           X        Y  CentroidNumber
# 0  1.242171  2.17911               0
#           X        Y  CentroidNumber
# 0  1.245902  2.19687               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.155159  2.048112               0
#           X         Y  CentroidNumber
# 0  1.131189  2.054274               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  0.796059  1.630031               0
#           X         Y  CentroidNumber
# 0  0.767358  1.623129               0
#           X         Y  CentroidNumber
# 0  0.724811  1.657511               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  0.555572  1.461531               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  0.339888  1.404918               0
#           X         Y  CentroidNumber
# 0  0.278853  1.428414               0
#           X         Y  CentroidNumber
# 0  0.236984  1.426414               0
#           X         Y  CentroidNumber
# 0  0.203021  1.420927               0
#           X         Y  CentroidNumber
# 0  0.167524  1.428947               0
#           X         Y  CentroidNumber
# 0  0.183812  1.395858               0
#           X         Y  CentroidNumber
# 0  0.162897  1.372752               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.255269  1.344593               0
#           X         Y  CentroidNumber
# 0 -0.279799  1.353281               0
#           X         Y  CentroidNumber
# 0 -0.312748  1.368323               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.375389  1.389128               0
#           X         Y  CentroidNumber
# 0 -0.393752  1.370398               0
#           X         Y  CentroidNumber
# 0 -0.411138  1.390929               0
#           X         Y  CentroidNumber
# 0 -0.462595  1.406882               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.535576  1.414713               0
#           X         Y  CentroidNumber
# 0 -0.531063  1.402379               0
#           X         Y  CentroidNumber
# 0 -0.593407  1.442001               0
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0 -0.659253  1.43396               0
#           X         Y  CentroidNumber
# 0 -0.696425  1.409705               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.816002  1.407285               0
#           X         Y  CentroidNumber
# 0 -0.850474  1.386929               0
# Empty DataFrame
# Columns: []
# Index: []
#           X       Y  CentroidNumber
# 0 -0.885593  1.4284               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.991496  1.553884               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.016803  1.652762               0
#           X         Y  CentroidNumber
# 0 -1.009093  1.686435               0
#           X         Y  CentroidNumber
# 0 -1.073399  1.682315               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.126504  1.772988               0
#          X         Y  CentroidNumber
# 0 -1.11964  1.787335               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0 -1.149499  1.84018               0
#           X         Y  CentroidNumber
# 0 -1.212588  1.911735               0
#           X         Y  CentroidNumber
# 0 -1.330634  1.908473               0
#           X         Y  CentroidNumber
# 0 -1.340194  1.977224               0
#           X         Y  CentroidNumber
# 0 -1.259128  1.932659               0
#           X         Y  CentroidNumber
# 0 -1.246097  1.986546               0
#           X         Y  CentroidNumber
# 0 -1.279578  1.995062               0
#           X         Y  CentroidNumber
# 0 -1.261216  2.039631               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.234457  2.088195               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.393758  2.230296               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.422314  2.326847               0
#           X         Y  CentroidNumber
# 0 -1.476813  2.315935               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.424667  2.458756               0
#           X         Y  CentroidNumber
# 0 -1.329011  2.423265               0
#           X        Y  CentroidNumber
# 0 -1.320636  2.51081               0
#           X         Y  CentroidNumber
# 0 -1.192257  2.474229               0
#           X         Y  CentroidNumber
# 0 -1.381208  2.578874               0
# Empty DataFrame
# Columns: []
# Index: []
#         X         Y  CentroidNumber
# 0 -1.4726  2.630817               0
#           X         Y  CentroidNumber
# 0 -1.516592  2.704622               0
#           X         Y  CentroidNumber
# 0 -1.461849  2.717166               0
#           X        Y  CentroidNumber
# 0 -1.416111  2.75138               0
#           X         Y  CentroidNumber
# 0 -1.494924  2.836573               0
#           X         Y  CentroidNumber
# 0 -1.545977  2.863123               0
#           X         Y  CentroidNumber
# 0 -1.456282  2.902975               0
#           X         Y  CentroidNumber
# 0 -1.458211  2.890489               0
#           X         Y  CentroidNumber
# 0 -1.505203  2.929975               0
#           X         Y  CentroidNumber
# 0 -1.504144  2.919805               0
#           X         Y  CentroidNumber
# 0 -1.529566  2.969769               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.492876  3.012387               0
#           X         Y  CentroidNumber
# 0 -1.517842  3.084279               0
#           X         Y  CentroidNumber
# 0 -1.439558  3.144253               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.445568  3.194051               0
#           X         Y  CentroidNumber
# 0 -1.442488  3.201956               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.359992  3.274641               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.407143  3.384776               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.462996  3.417421               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.366386  3.627574               0
#           X         Y  CentroidNumber
# 0 -1.369061  3.617155               0
#           X         Y  CentroidNumber
# 0 -1.374303  3.651611               0
#           X        Y  CentroidNumber
# 0 -1.357848  3.66855               0
#           X         Y  CentroidNumber
# 0 -1.384719  3.701168               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.373298  3.734238               0
#          X         Y  CentroidNumber
# 0 -1.29434  3.738558               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.396705  3.801471               0
#           X        Y  CentroidNumber
# 0 -1.402493  3.82349               0
#           X         Y  CentroidNumber
# 0 -1.398649  3.837106               0
#           X         Y  CentroidNumber
# 0 -1.313842  3.868456               0
#           X         Y  CentroidNumber
# 0 -1.297773  3.872867               0
#           X         Y  CentroidNumber
# 0 -1.360726  3.930516               0
#          X         Y  CentroidNumber
# 0 -1.29401  3.945782               0
#           X         Y  CentroidNumber
# 0 -1.213911  3.927211               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.207383  3.962389               0
#           X         Y  CentroidNumber
# 0 -1.333321  4.015414               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.327704  4.094863               0
#          X         Y  CentroidNumber
# 0 -1.22526  4.079582               0
# Empty DataFrame
# Columns: []
# Index: []
#          X        Y  CentroidNumber
# 0 -1.40876  4.04567               0
#           X        Y  CentroidNumber
# 0 -1.423849  4.05598               0
#           X         Y  CentroidNumber
# 0 -1.291648  4.087186               0
#           X         Y  CentroidNumber
# 0 -1.227872  4.111654               0
#           X         Y  CentroidNumber
# 0 -1.263057  4.163914               0
#           X         Y  CentroidNumber
# 0 -1.400605  4.166117               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.419687  4.268355               0
#           X         Y  CentroidNumber
# 0 -1.387964  4.265245               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.375524  4.309568               0
#           X         Y  CentroidNumber
# 0 -1.246975  4.330036               0
#           X         Y  CentroidNumber
# 0 -1.142882  4.346044               0
#           X         Y  CentroidNumber
# 0 -1.137231  4.289635               0
#           X         Y  CentroidNumber
# 0 -1.266647  4.378413               0
#           X         Y  CentroidNumber
# 0 -1.326917  4.380136               0
#           X         Y  CentroidNumber
# 0 -1.239707  4.308198               0
#           X        Y  CentroidNumber
# 0 -1.167859  4.34172               0
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0 -1.11111  4.408264               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.107636  4.475449               0
#           X         Y  CentroidNumber
# 0 -1.069313  4.480054               0
#           X        Y  CentroidNumber
# 0 -1.117811  4.48971               0
#           X         Y  CentroidNumber
# 0 -1.043877  4.576514               0
#           X        Y  CentroidNumber
# 0 -1.060392  4.53964               0
#           X         Y  CentroidNumber
# 0 -1.065847  4.562175               0
#           X         Y  CentroidNumber
# 0 -1.057109  4.602766               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.943741  4.610812               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0 -0.97084  4.668184               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.195275  4.959335               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.218571  4.894163               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.681279  4.883046               0
#           X         Y  CentroidNumber
# 0  1.196436  4.845543               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0  1.47965  4.832194               0
#           X         Y  CentroidNumber
# 0  1.564274  4.804447               0
#          X         Y  CentroidNumber
# 0  1.65567  4.761675               0
#           X        Y  CentroidNumber
# 0  1.252981  4.76402               0
#           X         Y  CentroidNumber
# 0  1.587305  4.738492               0
#           X         Y  CentroidNumber
# 0  1.222078  4.676768               0
#           X         Y  CentroidNumber
# 0  1.323738  4.663569               0
#           X         Y  CentroidNumber
# 0  1.474413  4.685776               0
#           X         Y  CentroidNumber
# 0  1.274632  4.661034               0
#           X        Y  CentroidNumber
# 0  1.269642  4.60184               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0  1.28809  4.534617               0
#          X         Y  CentroidNumber
# 0  1.54084  4.547189               0
#           X       Y  CentroidNumber
# 0  1.305492  4.5062               0
#           X         Y  CentroidNumber
# 0  1.529975  4.499692               0
#           X         Y  CentroidNumber
# 0  1.522377  4.451987               0
#           X         Y  CentroidNumber
# 0  1.482111  4.469868               0
#           X         Y  CentroidNumber
# 0  1.490807  4.426763               0
#           X         Y  CentroidNumber
# 0  1.619215  4.371278               0
#           X         Y  CentroidNumber
# 0  1.595779  4.393137               0
#           X         Y  CentroidNumber
# 0  1.676426  4.336911               0
#           X         Y  CentroidNumber
# 0  1.685194  4.312405               0
#           X         Y  CentroidNumber
# 0  1.645971  4.313329               0
#           X         Y  CentroidNumber
# 0  1.666555  4.308815               0
#           X         Y  CentroidNumber
# 0  1.726767  4.271195               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.730282  4.217452               0
#           X         Y  CentroidNumber
# 0  1.632403  4.210669               0
#           X         Y  CentroidNumber
# 0  1.382301  4.154416               0
#           X         Y  CentroidNumber
# 0  1.564699  4.186394               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.607822  4.025345               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.693115  3.979966               0
#           X         Y  CentroidNumber
# 0  1.592761  3.942883               0
#           X         Y  CentroidNumber
# 0  1.604096  3.940993               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0  1.32826  3.812802               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.368916  3.765268               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.574701  3.625802               0
#           X         Y  CentroidNumber
# 0  1.535427  3.617464               0
#           X         Y  CentroidNumber
# 0  1.628532  3.591531               0
#           X         Y  CentroidNumber
# 0  1.550828  3.601376               0
#           X         Y  CentroidNumber
# 0  1.568752  3.599586               0
#           X         Y  CentroidNumber
# 0  1.597221  3.543998               0
#           X         Y  CentroidNumber
# 0  1.597296  3.549628               0
#           X         Y  CentroidNumber
# 0  1.529579  3.557088               0
#           X         Y  CentroidNumber
# 0  1.616778  3.539889               0
#           X         Y  CentroidNumber
# 0  1.680288  3.500692               0
#           X         Y  CentroidNumber
# 0  1.647022  3.513029               0
#           X         Y  CentroidNumber
# 0  1.618538  3.518316               0
#           X         Y  CentroidNumber
# 0  1.515367  3.512177               0
#          X         Y  CentroidNumber
# 0  1.48948  3.478055               0
#           X         Y  CentroidNumber
# 0  1.431907  3.477591               0
#           X         Y  CentroidNumber
# 0  1.433366  3.490122               0
#           X         Y  CentroidNumber
# 0  1.405594  3.500252               0
#           X         Y  CentroidNumber
# 0  1.362318  3.439921               0
#           X         Y  CentroidNumber
# 0  1.406886  3.344812               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0  1.412435  3.59111               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.540166  3.621559               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.456059  3.688042               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.624831  3.762359               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.383644  3.798116               0
#           X         Y  CentroidNumber
# 0  1.421753  3.794568               0
#           X         Y  CentroidNumber
# 0  1.378291  3.810428               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.562117  3.924501               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.607652  4.001038               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.403564  3.957373               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.643828  4.142984               0
#           X         Y  CentroidNumber
# 0  1.613467  4.167767               0
#           X         Y  CentroidNumber
# 0  1.364701  4.214714               0
#           X         Y  CentroidNumber
# 0  1.758081  4.205779               0
#           X         Y  CentroidNumber
# 0  1.671925  4.256978               0
#           X         Y  CentroidNumber
# 0  1.664744  4.243417               0
#           X         Y  CentroidNumber
# 0  1.734707  4.308138               0
# Empty DataFrame
# Columns: []
# Index: []
#          X         Y  CentroidNumber
# 0  1.83952  4.320011               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.731884  4.324654               0
#           X        Y  CentroidNumber
# 0  1.701987  4.35534               0
#           X         Y  CentroidNumber
# 0  1.726263  4.385165               0
#           X         Y  CentroidNumber
# 0  1.776412  4.369973               0
#           X         Y  CentroidNumber
# 0  1.667586  4.443963               0
#           X        Y  CentroidNumber
# 0  1.673488  4.45922               0
#           X         Y  CentroidNumber
# 0  1.362901  4.523118               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.616484  4.549032               0
#           X         Y  CentroidNumber
# 0  1.396531  4.546719               0
#           X         Y  CentroidNumber
# 0  1.614464  4.559896               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.607499  4.585876               0
#          X         Y  CentroidNumber
# 0  1.28744  4.555111               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.609714  4.648551               0
#           X         Y  CentroidNumber
# 0  1.265385  4.640998               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0  1.320741  4.73689               0
#           X         Y  CentroidNumber
# 0  1.306828  4.799195               0
#           X         Y  CentroidNumber
# 0  1.260822  4.840757               0
#           X         Y  CentroidNumber
# 0  1.211707  4.850812               0
#           X         Y  CentroidNumber
# 0  1.216147  4.896301               0
#           X         Y  CentroidNumber
# 0  1.547572  4.874648               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.249771  4.940918               0
#           X        Y  CentroidNumber
# 0  1.276654  4.92771               0
#          X         Y  CentroidNumber
# 0  1.29009  4.915466               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.192818  4.945667               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0  1.192997  5.010992               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.915934  4.984046               0
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0 -0.921372  4.98798               0
#           X         Y  CentroidNumber
# 0 -0.915426  4.934358               0
#           X         Y  CentroidNumber
# 0 -0.916526  4.928979               0
#           X         Y  CentroidNumber
# 0 -0.892833  4.906159               0
#           X         Y  CentroidNumber
# 0 -0.957932  4.912673               0
#           X         Y  CentroidNumber
# 0 -0.973433  4.869551               0
#          X         Y  CentroidNumber
# 0 -1.01888  4.854578               0
#          X         Y  CentroidNumber
# 0 -1.03195  4.839302               0
#           X         Y  CentroidNumber
# 0 -1.047305  4.799126               0
#           X         Y  CentroidNumber
# 0 -1.018061  4.783307               0
#           X         Y  CentroidNumber
# 0 -1.149955  4.741602               0
#           X       Y  CentroidNumber
# 0 -1.145149  4.7093               0
#           X         Y  CentroidNumber
# 0 -1.225003  4.698167               0
#           X         Y  CentroidNumber
# 0 -1.181533  4.666612               0
#           X         Y  CentroidNumber
# 0 -1.195038  4.668481               0
#           X        Y  CentroidNumber
# 0 -1.172249  4.64846               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.340748  4.574288               0
#           X         Y  CentroidNumber
# 0 -1.345011  4.579708               0
#           X         Y  CentroidNumber
# 0 -1.399207  4.542782               0
#          X         Y  CentroidNumber
# 0 -1.14827  4.476336               0
#           X         Y  CentroidNumber
# 0 -1.127221  4.491128               0
#           X         Y  CentroidNumber
# 0 -1.232381  4.445458               0
#           X         Y  CentroidNumber
# 0 -1.364697  4.431175               0
#           X         Y  CentroidNumber
# 0 -1.217368  4.342475               0
#           X         Y  CentroidNumber
# 0 -1.309359  4.337984               0
#           X         Y  CentroidNumber
# 0 -1.489637  4.314552               0
#           X         Y  CentroidNumber
# 0 -1.179554  4.280942               0
#           X         Y  CentroidNumber
# 0 -1.335751  4.238957               0
#           X         Y  CentroidNumber
# 0 -1.380392  4.224955               0
#           X         Y  CentroidNumber
# 0 -1.198337  4.178115               0
# Empty DataFrame
# Columns: []
# Index: []
#           X        Y  CentroidNumber
# 0 -1.427155  4.14215               0
#           X         Y  CentroidNumber
# 0 -1.370128  4.137746               0
#           X         Y  CentroidNumber
# 0 -1.433406  4.088907               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.371587  4.020589               0
#           X        Y  CentroidNumber
# 0 -1.366115  3.99367               0
#           X         Y  CentroidNumber
# 0 -1.199427  3.911498               0
#           X         Y  CentroidNumber
# 0 -1.422533  3.895219               0
#           X         Y  CentroidNumber
# 0 -1.274937  3.898584               0
#           X         Y  CentroidNumber
# 0 -1.461962  3.874842               0
#           X         Y  CentroidNumber
# 0 -1.518069  3.863618               0
#           X         Y  CentroidNumber
# 0 -1.479918  3.850703               0
#           X         Y  CentroidNumber
# 0 -1.485036  3.763381               0
#           X         Y  CentroidNumber
# 0 -1.648247  3.765869               0
#           X         Y  CentroidNumber
# 0 -1.333566  3.742435               0
#           X         Y  CentroidNumber
# 0 -1.261142  3.680378               0
#          X         Y  CentroidNumber
# 0 -1.49602  3.669583               0
#           X         Y  CentroidNumber
# 0 -1.416753  3.622923               0
#           X         Y  CentroidNumber
# 0 -1.460178  3.586646               0
#           X         Y  CentroidNumber
# 0 -1.469046  3.584728               0
#           X         Y  CentroidNumber
# 0 -1.379012  3.507021               0
#           X         Y  CentroidNumber
# 0 -1.459389  3.481605               0
#          X         Y  CentroidNumber
# 0 -1.48749  3.466201               0
#           X         Y  CentroidNumber
# 0 -1.473375  3.424376               0
#           X         Y  CentroidNumber
# 0 -1.427059  3.396191               0
#           X         Y  CentroidNumber
# 0 -1.414048  3.381945               0
#           X         Y  CentroidNumber
# 0 -1.521468  3.325874               0
#           X         Y  CentroidNumber
# 0 -1.224954  3.285091               0
#           X        Y  CentroidNumber
# 0 -1.471774  3.26435               0
#           X         Y  CentroidNumber
# 0 -1.378899  3.223185               0
#           X        Y  CentroidNumber
# 0 -1.392915  3.18423               0
#           X        Y  CentroidNumber
# 0 -1.509422  3.16116               0
#           X        Y  CentroidNumber
# 0 -1.544651  3.11528               0
#           X         Y  CentroidNumber
# 0 -1.535824  3.096868               0
#          X         Y  CentroidNumber
# 0 -1.49486  3.078997               0
#           X         Y  CentroidNumber
# 0 -1.493638  3.006012               0
#           X         Y  CentroidNumber
# 0 -1.526282  2.999043               0
#           X        Y  CentroidNumber
# 0 -1.634363  2.98072               0
#           X         Y  CentroidNumber
# 0 -1.540086  2.942353               0
#           X         Y  CentroidNumber
# 0 -1.571399  2.924353               0
#           X         Y  CentroidNumber
# 0 -1.593713  2.910061               0
#           X         Y  CentroidNumber
# 0 -1.542433  2.878118               0
#           X         Y  CentroidNumber
# 0 -1.544739  2.828001               0
#          X         Y  CentroidNumber
# 0 -1.52895  2.818189               0
#           X         Y  CentroidNumber
# 0 -1.529308  2.806163               0
#           X         Y  CentroidNumber
# 0 -1.542927  2.769543               0
#           X         Y  CentroidNumber
# 0 -1.674155  2.735775               0
#           X         Y  CentroidNumber
# 0 -1.585853  2.722488               0
#           X         Y  CentroidNumber
# 0 -1.500446  2.668069               0
#           X         Y  CentroidNumber
# 0 -1.497597  2.668958               0
#           X         Y  CentroidNumber
# 0 -1.518769  2.621177               0
#           X         Y  CentroidNumber
# 0 -1.566387  2.600293               0
#           X         Y  CentroidNumber
# 0 -1.502827  2.568194               0
#           X         Y  CentroidNumber
# 0 -1.438088  2.546927               0
#           X         Y  CentroidNumber
# 0 -1.378254  2.531319               0
#           X        Y  CentroidNumber
# 0 -1.397448  2.51311               0
#           X         Y  CentroidNumber
# 0 -1.431773  2.486285               0
#           X         Y  CentroidNumber
# 0 -1.368982  2.454831               0
#           X         Y  CentroidNumber
# 0 -1.405264  2.446199               0
#          X        Y  CentroidNumber
# 0 -1.34234  2.44262               0
#          X         Y  CentroidNumber
# 0 -1.33307  2.336541               0
#           X         Y  CentroidNumber
# 0 -1.358992  2.328207               0
#           X         Y  CentroidNumber
# 0 -1.248394  2.276477               0
#           X         Y  CentroidNumber
# 0 -1.269408  2.223716               0
#           X         Y  CentroidNumber
# 0 -1.419174  2.257598               0
#           X         Y  CentroidNumber
# 0 -1.405812  2.217097               0
#           X         Y  CentroidNumber
# 0 -1.430025  2.206633               0
#           X         Y  CentroidNumber
# 0 -1.384625  2.153468               0
#           X         Y  CentroidNumber
# 0 -1.363244  2.147734               0
#           X         Y  CentroidNumber
# 0 -1.346381  2.080349               0
#           X         Y  CentroidNumber
# 0 -1.252099  2.064292               0
#           X         Y  CentroidNumber
# 0 -1.387099  2.085476               0
#           X         Y  CentroidNumber
# 0 -1.345439  2.037121               0
#           X         Y  CentroidNumber
# 0 -1.290595  2.036052               0
#           X         Y  CentroidNumber
# 0 -1.287969  2.032419               0
#           X         Y  CentroidNumber
# 0 -1.311385  1.942901               0
#           X         Y  CentroidNumber
# 0 -1.236988  1.961305               0
#           X         Y  CentroidNumber
# 0 -1.162777  1.864752               0
#           X         Y  CentroidNumber
# 0 -1.198891  1.910272               0
#           X        Y  CentroidNumber
# 0 -1.205553  1.86224               0
#           X        Y  CentroidNumber
# 0 -1.166043  1.85262               0
#           X         Y  CentroidNumber
# 0 -1.158334  1.862859               0
#           X         Y  CentroidNumber
# 0 -1.096287  1.824486               0
#           X         Y  CentroidNumber
# 0 -1.119382  1.786055               0
#           X        Y  CentroidNumber
# 0 -1.021168  1.72368               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -1.045616  1.544661               0
#           X         Y  CentroidNumber
# 0 -1.035998  1.515261               0
#          X         Y  CentroidNumber
# 0 -1.03475  1.524653               0
#           X         Y  CentroidNumber
# 0 -1.061899  1.559928               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.928434  1.481581               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.868417  1.417076               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.754225  1.445842               0
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.721264  1.441768               0
#           X         Y  CentroidNumber
# 0 -0.711932  1.454284               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#           X         Y  CentroidNumber
# 0 -0.546526  1.285519               0
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
associatedDf = pd.DataFrame({'MeasuredRange':correctAssociationMatrix[:,0], 
                             'MeasuredTheta': correctAssociationMatrix[:,1],
                             'CentroidNumber': correctAssociationMatrix[:,2]})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-25692c49e13e> in <module>
#       1 correctAssociationMatrix = np.array([5, 1, 0])
# ----> 2 associatedDf = pd.DataFrame({'MeasuredRange':correctAssociationMatrix[:,0],
#       3                              'MeasuredTheta': correctAssociationMatrix[:,1],
#       4                              'CentroidNumber': correctAssociationMatrix[:,2]})
#
# IndexError: too many indices for array

# %%
associationMatrix.shape
# Out:
# (3,)

# %%
polarCentroidFrameMeasurement.values[centroid]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-c55681676c7d> in <module>
# ----> 1 polarCentroidFrameMeasurement.values[centroid]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ### Unit Testing

# %%
#test predict step
x = np.expand_dims(np.array([1,0.5,0,0]), axis=1) #previous state
xPred = predictStep(x, A) #predicted state
xPred
# Out:
# array([[1.025],
#        [0.5  ],
#        [0.   ],
#        [0.   ]])

# %%
#test innovation
#use xPred from previous step
# innovation(xPred, Pd, z, H, R)
z = np.expand_dims(np.array([1,0.5]), axis=1) #create column vector
innovation = innovationStep(xPred, z, H)
innovation
# Out:
# array([[-0.025],
#        [ 0.5  ]])

# %%
#test update step
xNew = UpdateStep(xPred, innovation, K)
xNew
# Out:
# array([[0.88132417],
#        [0.49641259],
#        [0.38132417],
#        [0.0095212 ]])

# %%
#test centroid dataset
#centroidDf_A contains 2 centroids
centroidDfCartesian_A = pd.DataFrame({'CentroidNumber':np.arange(0,2), 
                             'X':np.array([-1,0]), 
                             'Y':np.array([3,1])})
#centroidDf_B contains 2 centroids and continues on from centroidDf_A
centroidDfCartesian_B = pd.DataFrame({'CentroidNumber':np.arange(0,2), 
                             'X':np.array([-1,0.5]), 
                             'Y':np.array([2.5,0.7])})
#centroidDf_C contains 3 centroids continuing from centroidDf_B
centroidDfCartesian_C = pd.DataFrame({'CentroidNumber':np.arange(0,3), 
                             'X':np.array([-1,0.7, 0.3]), 
                             'Y':np.array([1.2,0.5, 3.2])})

centroidDfCartesian_D = pd.DataFrame([])

#contains the centroid frames, where each frame represents a mmWave capture frame
centroidFramesCartesianMeasurement = [centroidDfCartesian_A, centroidDfCartesian_B,centroidDfCartesian_D]

# %%
filteredCentroidPolarFrames = list()

#load in frames
for centroidFrame in centroidFramesCartesianMeasurement:
    filteredPolarFrame = np.array([])
    
    if len(filteredCentroidPolarFrames) == 0: #first iteration of the kalman filter
        polarCentroidFrameMeasurement = convertCartesianToPolar(centroidFrame)
        for centroid in polarCentroidFrameMeasurement['CentroidNumber']:
            x = np.expand_dims(np.array([0,0,0,0]), axis=1) #initialise 
            xPred = predictStep(x, A)
            measurement = np.expand_dims(polarCentroidFrameMeasurement.values[centroid][1:], axis=1)
            innovation = innovationStep(xPred, measurement, H)
            xUpdate = UpdateStep(xPred, innovation, K)
            if len(filteredPolarFrame) == 0:
                filteredPolarFrame = xUpdate
            else:
                filteredPolarFrame = np.hstack((filteredPolarFrame,xUpdate))
    else:
        
        associatedDf, xPredDf = dataAssociation(centroidFrame, filteredCentroidPolarFrames)
        overallDf = pd.merge(associatedDf, xPredDf, on='CentroidNumber', how='inner')
        for index in range(0 , overallDf.shape[0]):
            centroidData = overallDf.loc[index]
            measurement = np.expand_dims(np.array([centroidData.MeasuredRange, centroidData.MeasuredTheta]), axis=1)
            xPred = np.expand_dims(np.array([centroidData.PredictedRange, centroidData.PredictedDoppler,centroidData.PredictedTheta, centroidData.PredictedAngularVelocity]), axis=1)
            innovation = innovationStep(xPred, measurement, H)
            xUpdate = UpdateStep(xPred, innovation, K)
            if len(filteredPolarFrame) == 0:
                filteredPolarFrame = xUpdate
            else:
                filteredPolarFrame = np.hstack((filteredPolarFrame,xUpdate))
                
    filteredPolarDf = pd.DataFrame(np.transpose(filteredPolarFrame))
    filteredPolarDf.columns = ['Filtered Range', 'Filtered Doppler', 'Filtered Theta', 'Filtered Angular Velocity']
    filteredPolarDf['CentroidNumber'] = pd.Series(np.arange(filteredPolarDf.shape[0]))
    filteredCentroidPolarFrames.append(filteredPolarDf)
# Out:
# DONE ASSOCIATING
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'X'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-297a1ff2c887> in <module>
#      19     else:
#      20
# ---> 21         associatedDf, xPredDf = dataAssociation(centroidFrame, filteredCentroidPolarFrames)
#      22         overallDf = pd.merge(associatedDf, xPredDf, on='CentroidNumber', how='inner')
#      23         for index in range(0 , overallDf.shape[0]):
#
# <ipython-input-5-f81c65642804> in dataAssociation(centroidFrame, filteredCentroidPolarFrames)
#       1 def dataAssociation(centroidFrame, filteredCentroidPolarFrames):
# ----> 2     rThetaMeasurement = convertCartesianToPolar(centroidFrame)
#       3     #predict
#       4     previousCentroids = filteredCentroidPolarFrames[-1]
#       5     xPredAll = np.array([])
#
# <ipython-input-6-8ef9a366971c> in convertCartesianToPolar(cartesianMeasurementCentroidDf)
#       1 #convert x,y to r,theta
#       2 def convertCartesianToPolar(cartesianMeasurementCentroidDf):
# ----> 3     measurementR = np.sqrt(np.square(cartesianMeasurementCentroidDf['X']) + np.square(cartesianMeasurementCentroidDf['Y']))
#       4     measurementTheta = np.arctan(cartesianMeasurementCentroidDf['Y']/cartesianMeasurementCentroidDf['X'])
#       5     polarCentroidDf = pd.DataFrame({'CentroidNumber':cartesianMeasurementCentroidDf['CentroidNumber'],
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'X'

# %%
filteredCentroidPolarFrames[0]
# Out:
#    Filtered Range  Filtered Doppler  Filtered Theta  \
# 0        2.684268          0.067023       -1.727055
# 1        0.357702          0.008931        0.928499
#
#    Filtered Angular Velocity  CentroidNumber
# 0                  -0.043122               0
# 1                   0.023183               1

# %%
filteredCentroidPolarFrames[1]
# Out:
#    Filtered Range  Filtered Doppler  Filtered Theta  \
# 0        0.729571          0.018205        0.819885
# 1        2.556696          0.063754       -1.326176
#
#    Filtered Angular Velocity  CentroidNumber
# 0                   0.020443               0
# 1                  -0.033059               1

# %%
distanceMAtrixTest = distanceMatrix[2,:] = np.inf

# %%
measurement
# Out:
# array([3.21403174, 1.47731955, 2.        ])

# %%
rThetaMeasurement['CentroidNumber']
# Out:
# 0    0
# 1    1
# 2    2
# Name: CentroidNumber, dtype: int32

# %%
rThetaMeasurement
# Out:
#    CentroidNumber         R     Theta
# 0               0  2.692582 -1.190290
# 1               1  0.860233  0.950547

# %%
correctAssociationMatrix
# Out:
# array([[ 0.86023253,  0.95054684],
#        [ 2.6925824 , -1.19028995]])

# %%
colIndex
# Out:
# 1
